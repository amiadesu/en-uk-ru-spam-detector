# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import optuna
import joblib

from typing import List
import string

# %%
RANDOM_STATE = 0
N_JOBS = 6

# %% [markdown]
# # Reading data

# %%
train_df = pd.read_csv("data/processed/train_english_spam_detection_dataset.csv")
train_df.head()
# Out:
#                                              message  spam
# 0  Had your contract mobile 11 Mnths? Latest Moto...     1
# 1  the lottery promotion company limited churchil...     1
# 2  would you re - flnance if you knew you ' d sav...     1
# 3  please see attached , clean and redline versio...     0
# 4  ilug wilson kamela attn sir madan strictly con...     1

# %%
X_train = train_df["message"]
y_train = train_df["spam"]

# %% [markdown]
# # Encoders

# %% [markdown]
# In this section we'll compare the learning speed of several different encoders for our texts as well as prepare different preprocessing approaches.

# %% [markdown]
# We should also note that all of our encoders are gonna tokenize text by characters and not by words for the reason that is we're trying to classify text and not to find some deep semantic meaning of it, for which separation by characters is a much better approach (it can handle typos and only "looks" for the character distribution by which language can be determined pretty accurately, but we still may be caring for characters order and for this reason we're gonna use custom n-grams parameter values).

# %% [markdown]
# ## Preprocessors

# %% [markdown]
# In this section we're gonna write some simple different preprocessors.

# %%
def simple_preprocessor(text: str) -> str:
    return text

# %%
def no_punctuation_preprocessor(text: str) -> str:
    blacklist_chars = string.punctuation
    translation_table = str.maketrans("", "", blacklist_chars)
    cleaned_text = text.translate(translation_table)
    return cleaned_text

# %%
preprocessors = {
    "simple": simple_preprocessor,
    "no_punct": no_punctuation_preprocessor
}

# %% [markdown]
# We're also gonna copy our preprocessor functions as a custom model to the file located at `../../app/models/transformers.py` in order to be able to use them from anywhere later without need to redefine them (and we also may need this for our final model to work properly).

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# scikin-learn's implementation of TF-IDF is offline, which means that it keeps everything in-memory and should be trained in one run. It may not be viable for training and tuning our models, but we still gonna check the perfomance of this approach as well.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer='char_wb', # We're caring only about characters in word bounds
    ngram_range=(1,3),
    max_features=100000,
    preprocessor=no_punctuation_preprocessor,
    lowercase=True,
)

# %% [markdown]
# Note that we're not using stopwords as they can be a crutial part in differentiating between languages from one language family (exactly Russian and Ukrainian).

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='char_wb', max_features=100000, ngram_range=(1, 3),
#                 preprocessor=<function no_punctuation_preprocessor at 0x0000013992D42980>)

# %% [markdown]
# As we can see, this TF-IDF implementation has been training for a pretty long time considering that we'll be tuning hyperparameters of both encoder and our classification model, so we're not likely to use it considering that it is also an offline implementation.

# %% [markdown]
# ## HashingVectorizer

# %% [markdown]
# HashingVectorizer is an online approach, which means that we can partially train it. Also, its scikit-learn implementation should be noticably faster than the implementation of TF-IDF (although it's resuls can be quite worse, but it's still faster to train which means that it's also faster to tune).

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1,3),
    n_features=2**20,
    lowercase=True,
    preprocessor=no_punctuation_preprocessor
)

# %%
vectorizer.fit_transform(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 21098433 stored elements and shape (44963, 1048576)>

# %% [markdown]
# As this vectorizer is online, it's fit is stateless, but it's whole expensive computation is performed during transform stage. In result we can see, that it's still faster than TF-IDF, so we'll use it during our hyperparameters tuning.

# %% [markdown]
# # Models

# %% [markdown]
# We'll try two different models - SGDClassifier and Multinomial NaiveBayes, both of which are pretty popular in text classification tasks.
#
# We're not gonna try other popular models, such as XGBoost and LightGBM, in this specific case due to the fact that they are gonna consume a lot more memory (proportional to `amount of rows` * `amount of features`) and be much slower (time of execution is proportional to `amount of rows` * `amount of features` * `amount of trees (weak learners)`) than our two models of choice.

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import cross_val_score

# %%
from utils.models.transformers import TextCleaner
from utils.models.language_detector import LanguageDetector

# %% [markdown]
# ## SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd_model_path = "models/dev/sgd_english_spam_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def sgdclassifier_objective(trial: optuna.Trial):
    # Word ngrams
    word_n_features_pow = trial.suggest_int("word_n_features_pow", 16, 21)
    word_ngram_max = trial.suggest_int("word_ngram_max", 1, 3)

    word_vectorizer = HashingVectorizer(
        analyzer='word',
        ngram_range=(1, word_ngram_max),
        n_features=2 ** word_n_features_pow,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # Characters inside words ngrams
    char_n_features_pow = trial.suggest_int("char_n_features_pow", 14, 18)
    char_ngram_min = trial.suggest_int("char_ngram_min", 2, 3)
    char_ngram_max = trial.suggest_int("char_ngram_max", 4, 6)

    char_vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(char_ngram_min, char_ngram_max),
        n_features=2 ** char_n_features_pow,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # Combined features vectorizer
    combined_features_vectorizer = FeatureUnion([
        ("word_features", word_vectorizer),
        ("char_features", char_vectorizer),
    ])

    # SGDClassifier hyperparameters
    alpha = trial.suggest_float("alpha", 1e-6, 1e-1, log=True)
    penalty = trial.suggest_categorical("penalty", ["l2", "elasticnet"])

    # ElasticNet mixing parameter, will be ignored by model if penalty is l2
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    clf = SGDClassifier(
        loss='log_loss', # LogisticRegression
        penalty=penalty,
        alpha=alpha,
        l1_ratio=l1_ratio,
        class_weight="balanced", # Crutial because we have big class imbalance in our training dataset
        random_state=RANDOM_STATE,
        n_jobs=N_JOBS
    )

    pipeline = Pipeline([
        ("features_vectorizer", combined_features_vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %% [markdown]
# Note that we skipped max_iter parameter because it does not impact partial_fit behaviour according to https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html.

# %%
study = optuna.create_study(direction="maximize")
study.optimize(sgdclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-02-16 15:51:48,638] A new study created in memory with name: no-name-935bc1fb-496e-4a99-aa56-c3bf56fd0ef1
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-02-16 15:53:19,607] Trial 0 finished with value: 0.8370967264158434 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 1, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 0.0015344770286216357, 'penalty': 'elasticnet', 'l1_ratio': 0.36589857424180516}. Best is trial 0 with value: 0.8370967264158434.
# [I 2026-02-16 15:54:54,260] Trial 1 finished with value: 0.9333884714071422 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 3, 'char_n_features_pow': 16, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 0.0001869490342689748, 'penalty': 'l2', 'l1_ratio': 0.6652428939196582}. Best is trial 1 with value: 0.9333884714071422.
# [I 2026-02-16 15:56:05,196] Trial 2 finished with value: 0.8393391365538792 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 1, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 0.009229902587161394, 'penalty': 'l2', 'l1_ratio': 0.6672352003506664}. Best is trial 1 with value: 0.9333884714071422.
# [I 2026-02-16 15:57:02,983] Trial 3 finished with value: 0.9348850812670312 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 1, 'char_n_features_pow': 18, 'char_ngram_min': 3, 'char_ngram_max': 6, 'alpha': 0.0002161943972598879, 'penalty': 'l2', 'l1_ratio': 0.24350913869429114}. Best is trial 3 with value: 0.9348850812670312.
# [I 2026-02-16 15:58:17,480] Trial 4 finished with value: 0.8863361940258025 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 0.0002872218336745868, 'penalty': 'elasticnet', 'l1_ratio': 0.9440504076669011}. Best is trial 3 with value: 0.9348850812670312.
# [I 2026-02-16 15:59:32,514] Trial 5 finished with value: 0.9674460591972736 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 2, 'char_n_features_pow': 16, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 1.6688214135645789e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.8716403088967274}. Best is trial 5 with value: 0.9674460591972736.
# [I 2026-02-16 16:00:39,609] Trial 6 finished with value: 0.9356600664300432 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 8.553526528868818e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.26820625871273496}. Best is trial 5 with value: 0.9674460591972736.
# [I 2026-02-16 16:01:53,893] Trial 7 finished with value: 0.5065102527623776 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 3, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.00895303944333446, 'penalty': 'elasticnet', 'l1_ratio': 0.8784294059848744}. Best is trial 5 with value: 0.9674460591972736.
# [I 2026-02-16 16:03:12,368] Trial 8 finished with value: 0.9653222250752739 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 3, 'char_n_features_pow': 15, 'char_ngram_min': 3, 'char_ngram_max': 6, 'alpha': 1.3686104223272218e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.4415377651128416}. Best is trial 5 with value: 0.9674460591972736.
# [I 2026-02-16 16:04:21,217] Trial 9 finished with value: 0.8166773180891864 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 1, 'char_n_features_pow': 17, 'char_ngram_min': 3, 'char_ngram_max': 6, 'alpha': 0.024511185155748627, 'penalty': 'l2', 'l1_ratio': 0.41197007686599885}. Best is trial 5 with value: 0.9674460591972736.
# [I 2026-02-16 16:05:07,239] Trial 10 finished with value: 0.9674069307296077 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 2, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 2.8847114795138334e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.0618083479203988}. Best is trial 5 with value: 0.9674460591972736.
# [I 2026-02-16 16:06:03,912] Trial 11 finished with value: 0.9678196087005757 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 2, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 1.2107742997998623e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.017198734260344205}. Best is trial 11 with value: 0.9678196087005757.
# [I 2026-02-16 16:06:50,133] Trial 12 finished with value: 0.9578161910050852 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 2, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 1.206630135444971e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.6835287109759032}. Best is trial 11 with value: 0.9678196087005757.
# [I 2026-02-16 16:07:47,748] Trial 13 finished with value: 0.9601465883559723 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 2, 'char_n_features_pow': 15, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 2.178482608557699e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.004622239857517585}. Best is trial 11 with value: 0.9678196087005757.
# [I 2026-02-16 16:08:55,371] Trial 14 finished with value: 0.9650704503926667 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 2, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 6.546781490804382e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.5870536394918152}. Best is trial 11 with value: 0.9678196087005757.
# [I 2026-02-16 16:10:04,553] Trial 15 finished with value: 0.9632304088646295 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 2, 'char_n_features_pow': 15, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 1.0527605360506262e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.8126270173017924}. Best is trial 11 with value: 0.9678196087005757.
# [I 2026-02-16 16:11:23,671] Trial 16 finished with value: 0.9527462109424413 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 3.511270414475627e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.13363958951540209}. Best is trial 11 with value: 0.9678196087005757.
# [I 2026-02-16 16:12:29,150] Trial 17 finished with value: 0.9641663871368699 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 3, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 4.301325024778819e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.7871603978309083}. Best is trial 11 with value: 0.9678196087005757.
# [I 2026-02-16 16:13:15,642] Trial 18 finished with value: 0.8958581586315958 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 3, 'char_n_features_pow': 17, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 0.0011793698888362331, 'penalty': 'l2', 'l1_ratio': 0.5359448300205641}. Best is trial 11 with value: 0.9678196087005757.
# [I 2026-02-16 16:14:44,363] Trial 19 finished with value: 0.949310854090967 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 2, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 4.136306567776085e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.19871698350568626}. Best is trial 11 with value: 0.9678196087005757.

# %%
study.best_params
# Out:
# {'word_n_features_pow': 16,
#  'word_ngram_max': 2,
#  'char_n_features_pow': 16,
#  'char_ngram_min': 3,
#  'char_ngram_max': 4,
#  'alpha': 1.2107742997998623e-06,
#  'penalty': 'elasticnet',
#  'l1_ratio': 0.017198734260344205}

# %% [markdown]
# ```
# {'word_n_features_pow': 16,
#  'word_ngram_max': 2,
#  'char_n_features_pow': 16,
#  'char_ngram_min': 3,
#  'char_ngram_max': 4,
#  'alpha': 1.2107742997998623e-06,
#  'penalty': 'elasticnet',
#  'l1_ratio': 0.017198734260344205}
# ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters into a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
sgd_best_params = {
    'word_n_features_pow': 16,
    'word_ngram_max': 2,
    'char_n_features_pow': 16,
    'char_ngram_min': 3,
    'char_ngram_max': 4,
    'alpha': 1.2107742997998623e-06,
    'penalty': 'elasticnet',
    'l1_ratio': 0.017198734260344205
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    sgd_params = study.best_params
except:
    sgd_params = sgd_best_params 

word_vectorizer = HashingVectorizer(
    analyzer='word',
    ngram_range=(1, sgd_params["word_ngram_max"]),
    n_features=2 ** sgd_params["word_n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

char_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(sgd_params["char_ngram_min"], sgd_params["char_ngram_max"]),
    n_features=2 ** sgd_params["char_n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

combined_features_vectorizer = FeatureUnion([
    ("word_features", word_vectorizer),
    ("char_features", char_vectorizer),
])

final_sgd_clf = SGDClassifier(
    loss='log_loss',
    penalty=sgd_params["penalty"],
    alpha=sgd_params["alpha"],
    l1_ratio=sgd_params["l1_ratio"],
    class_weight="balanced",
    random_state=RANDOM_STATE,
    n_jobs=N_JOBS
)

sgd_spam_detector = Pipeline([
    ("features_vectorizer", combined_features_vectorizer),
    ("classifier", final_sgd_clf)
])

# %%
sgd_spam_detector.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('features_vectorizer',
#                  FeatureUnion(transformer_list=[('word_features',
#                                                  HashingVectorizer(n_features=65536,
#                                                                    ngram_range=(1,
#                                                                                 2))),
#                                                 ('char_features',
#                                                  HashingVectorizer(analyzer='char_wb',
#                                                                    n_features=65536,
#                                                                    ngram_range=(3,
#                                                                                 4)))])),
#                 ('classifier',
#                  SGDClassifier(alpha=1.2107742997998623e-06,
#                                class_weight='balanced',
#                                l1_ratio=0.017198734260344205, loss='log_loss',
#                                n_jobs=6, penalty='elasticnet',
#                                random_state=0))])

# %%
joblib.dump(sgd_spam_detector, sgd_model_path)
# Out:
# ['models/dev/sgd_english_spam_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
sgd_model = joblib.load(sgd_model_path)
sgd_model
# Out:
# Pipeline(steps=[('features_vectorizer',
#                  FeatureUnion(transformer_list=[('word_features',
#                                                  HashingVectorizer(n_features=65536,
#                                                                    ngram_range=(1,
#                                                                                 2))),
#                                                 ('char_features',
#                                                  HashingVectorizer(analyzer='char_wb',
#                                                                    n_features=65536,
#                                                                    ngram_range=(3,
#                                                                                 4)))])),
#                 ('classifier',
#                  SGDClassifier(alpha=1.2107742997998623e-06,
#                                class_weight='balanced',
#                                l1_ratio=0.017198734260344205, loss='log_loss',
#                                n_jobs=6, penalty='elasticnet',
#                                random_state=0))])

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!

# %% [markdown]
# ## MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb_model_path = "models/dev/mnb_english_spam_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def mnbclassifier_objective(trial: optuna.Trial):
    # Word ngrams
    word_n_features_pow = trial.suggest_int("word_n_features_pow", 16, 21)
    word_ngram_max = trial.suggest_int("word_ngram_max", 1, 3)

    word_vectorizer = HashingVectorizer(
        analyzer='word',
        ngram_range=(1, word_ngram_max),
        n_features=2 ** word_n_features_pow,
        alternate_sign=False, # Values must be non-negative for MultinomialNB
        norm='l2',
        lowercase=True
    )

    # Characters inside words ngrams
    char_n_features_pow = trial.suggest_int("char_n_features_pow", 14, 18)
    char_ngram_min = trial.suggest_int("char_ngram_min", 2, 3)
    char_ngram_max = trial.suggest_int("char_ngram_max", 4, 6)

    char_vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(char_ngram_min, char_ngram_max),
        n_features=2 ** char_n_features_pow,
        alternate_sign=False, # Values must be non-negative for MultinomialNB
        norm='l2',
        lowercase=True
    )

    # Combined features vectorizer
    combined_features_vectorizer = FeatureUnion([
        ("word_features", word_vectorizer),
        ("char_features", char_vectorizer),
    ])

    # MultinomialNB hyperparameters
    alpha = trial.suggest_float("alpha", 1e-10, 10.0, log=True)
    fit_prior = trial.suggest_categorical("fit_prior", [True, False])

    clf = MultinomialNB(
        alpha=alpha,
        fit_prior=fit_prior
    )

    pipeline = Pipeline([
        ("features_vectorizer", combined_features_vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(mnbclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-02-16 16:20:11,474] A new study created in memory with name: no-name-50270047-24cd-4ae4-b217-565fde742d61
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-02-16 16:21:25,065] Trial 0 finished with value: 0.9414267657535174 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 7.083412315401423e-10, 'fit_prior': False}. Best is trial 0 with value: 0.9414267657535174.
# [I 2026-02-16 16:22:09,898] Trial 1 finished with value: 0.9441792333128145 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 1, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 2.6562194852236175e-06, 'fit_prior': True}. Best is trial 1 with value: 0.9441792333128145.
# [I 2026-02-16 16:23:11,120] Trial 2 finished with value: 0.934894117004097 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 2, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 0.3620637030737649, 'fit_prior': False}. Best is trial 1 with value: 0.9441792333128145.
# [I 2026-02-16 16:24:25,095] Trial 3 finished with value: 0.9305233363643867 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 1, 'char_n_features_pow': 16, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 0.022262323872663806, 'fit_prior': False}. Best is trial 1 with value: 0.9441792333128145.
# [I 2026-02-16 16:25:33,147] Trial 4 finished with value: 0.9452344291305979 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 3, 'char_ngram_max': 6, 'alpha': 7.223022056564369e-06, 'fit_prior': True}. Best is trial 4 with value: 0.9452344291305979.
# [I 2026-02-16 16:26:28,565] Trial 5 finished with value: 0.9282480339555906 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 3, 'char_n_features_pow': 17, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 2.210861620666029e-07, 'fit_prior': False}. Best is trial 4 with value: 0.9452344291305979.
# [I 2026-02-16 16:27:21,533] Trial 6 finished with value: 0.9351448222293506 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 6.088638795843551e-09, 'fit_prior': True}. Best is trial 4 with value: 0.9452344291305979.
# [I 2026-02-16 16:28:39,933] Trial 7 finished with value: 0.9410955090744325 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 1.5502614361656773e-09, 'fit_prior': True}. Best is trial 4 with value: 0.9452344291305979.
# [I 2026-02-16 16:30:07,842] Trial 8 finished with value: 0.4663126277572401 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 5.633388435010055, 'fit_prior': True}. Best is trial 4 with value: 0.9452344291305979.
# [I 2026-02-16 16:31:10,432] Trial 9 finished with value: 0.9584931168812049 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.019087439556281498, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:32:30,068] Trial 10 finished with value: 0.9537129003883437 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 3, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.00925493475696602, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:33:36,235] Trial 11 finished with value: 0.9539105022198013 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 3, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.0011293737118851595, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:35:02,912] Trial 12 finished with value: 0.9502362220865995 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 3, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.0004329480617673229, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:36:09,750] Trial 13 finished with value: 0.9485981533791404 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 3, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.0005200008833344112, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:37:28,366] Trial 14 finished with value: 0.9518996141302196 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 2, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.0005029166292273293, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:38:44,908] Trial 15 finished with value: 0.9513993342223719 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 3, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 0.09227374568143588, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:40:01,144] Trial 16 finished with value: 0.9525804325421438 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 2, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 7.876565264347099e-05, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:41:03,622] Trial 17 finished with value: 0.5493118631284689 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 2, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 8.428275195152077, 'fit_prior': True}. Best is trial 9 with value: 0.9584931168812049.
# [I 2026-02-16 16:42:24,519] Trial 18 finished with value: 0.9594125163083419 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 3, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.01038499332509461, 'fit_prior': False}. Best is trial 18 with value: 0.9594125163083419.
# [I 2026-02-16 16:43:37,471] Trial 19 finished with value: 0.8429233064276213 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 2, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 0.37269800373232215, 'fit_prior': False}. Best is trial 18 with value: 0.9594125163083419.

# %%
study.best_params
# Out:
# {'word_n_features_pow': 21,
#  'word_ngram_max': 3,
#  'char_n_features_pow': 17,
#  'char_ngram_min': 2,
#  'char_ngram_max': 4,
#  'alpha': 0.01038499332509461,
#  'fit_prior': False}

# %% [markdown]
# ```
# {'word_n_features_pow': 21,
#  'word_ngram_max': 3,
#  'char_n_features_pow': 17,
#  'char_ngram_min': 2,
#  'char_ngram_max': 4,
#  'alpha': 0.01038499332509461,
#  'fit_prior': False}
#  ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters to a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
mnb_best_params = {
    'word_n_features_pow': 21,
    'word_ngram_max': 3,
    'char_n_features_pow': 17,
    'char_ngram_min': 2,
    'char_ngram_max': 4,
    'alpha': 0.01038499332509461,
    'fit_prior': False
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    mnb_params = study.best_params
except:
    mnb_params = mnb_best_params 

word_vectorizer = HashingVectorizer(
    analyzer='word',
    ngram_range=(1, mnb_params["word_ngram_max"]),
    n_features=2 ** mnb_params["word_n_features_pow"],
    alternate_sign=False,
    norm='l2',
    lowercase=True
)

char_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(mnb_params["char_ngram_min"], mnb_params["char_ngram_max"]),
    n_features=2 ** mnb_params["char_n_features_pow"],
    alternate_sign=False,
    norm='l2',
    lowercase=True
)

combined_features_vectorizer = FeatureUnion([
    ("word_features", word_vectorizer),
    ("char_features", char_vectorizer),
])

final_mnb_clf = MultinomialNB(
    alpha=mnb_params["alpha"],
    fit_prior=mnb_params["fit_prior"]
)

mnb_spam_detector = Pipeline([
    ("features_vectorizer", combined_features_vectorizer),
    ("classifier", final_mnb_clf)
])

# %%
mnb_spam_detector.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('features_vectorizer',
#                  FeatureUnion(transformer_list=[('word_features',
#                                                  HashingVectorizer(alternate_sign=False,
#                                                                    n_features=2097152,
#                                                                    ngram_range=(1,
#                                                                                 3))),
#                                                 ('char_features',
#                                                  HashingVectorizer(alternate_sign=False,
#                                                                    analyzer='char_wb',
#                                                                    n_features=131072,
#                                                                    ngram_range=(2,
#                                                                                 4)))])),
#                 ('classifier',
#                  MultinomialNB(alpha=0.01038499332509461, fit_prior=False))])

# %%
joblib.dump(mnb_spam_detector, mnb_model_path)
# Out:
# ['models/dev/mnb_english_spam_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
mnb_model = joblib.load(mnb_model_path)
mnb_model
# Out:
# Pipeline(steps=[('features_vectorizer',
#                  FeatureUnion(transformer_list=[('word_features',
#                                                  HashingVectorizer(alternate_sign=False,
#                                                                    n_features=2097152,
#                                                                    ngram_range=(1,
#                                                                                 3))),
#                                                 ('char_features',
#                                                  HashingVectorizer(alternate_sign=False,
#                                                                    analyzer='char_wb',
#                                                                    n_features=131072,
#                                                                    ngram_range=(2,
#                                                                                 4)))])),
#                 ('classifier',
#                  MultinomialNB(alpha=0.01038499332509461, fit_prior=False))])

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!
