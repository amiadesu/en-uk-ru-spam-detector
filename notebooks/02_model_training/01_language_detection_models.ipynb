# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import optuna
import joblib

from typing import List
import string

# %%
RANDOM_STATE = 0
N_JOBS = 6

# %% [markdown]
# # Reading data

# %%
train_df = pd.read_csv("data/processed/train_language_detection_dataset.csv")
train_df.head()
# Out:
#                                             sentence lan_code
# 0                            Откуда ты о них знаешь?      rus
# 1  Tom persuaded his mother to lend him the car f...      eng
# 2                               Let's mop the floor.      eng
# 3  Tom leaves his dog in the house when he's at w...      eng
# 4                                 Они с ним любезны.      rus

# %%
X_train = train_df["sentence"]
y_train = train_df["lan_code"]

# %% [markdown]
# # Encoders

# %% [markdown]
# In this section we'll compare the learning speed of several different encoders for our texts as well as prepare different preprocessing approaches.

# %% [markdown]
# We should also note that all of our encoders are gonna tokenize text by characters and not by words for the reason that is we're trying to classify text and not to find some deep semantic meaning of it, for which separation by characters is a much better approach (it can handle typos and only "looks" for the character distribution by which language can be determined pretty accurately, but we still may be caring for characters order and for this reason we're gonna use custom n-grams parameter values).

# %% [markdown]
# ## Preprocessors

# %% [markdown]
# In this section we're gonna write some simple different preprocessors.

# %%
def simple_preprocessor(text: str) -> str:
    return text

# %%
def no_punctuation_preprocessor(text: str) -> str:
    blacklist_chars = string.punctuation
    translation_table = str.maketrans("", "", blacklist_chars)
    cleaned_text = text.translate(translation_table)
    return cleaned_text

# %%
preprocessors = {
    "simple": simple_preprocessor,
    "no_punct": no_punctuation_preprocessor
}

# %% [markdown]
# We're also gonna copy our preprocessor functions as a custom model to the file located at `../../app/models/transformers.py` in order to be able to use them from anywhere later without need to redefine them (and we also may need this for our final model to work properly).

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# scikin-learn's implementation of TF-IDF is offline, which means that it keeps everything in-memory and should be trained in one run. It may not be viable for training and tuning our models, but we still gonna check the perfomance of this approach as well.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer='char_wb', # We're caring only about characters in word bounds
    ngram_range=(1,3),
    max_features=100000,
    preprocessor=no_punctuation_preprocessor,
    lowercase=True,
)

# %% [markdown]
# Note that we're not using stopwords as they can be a crutial part in differentiating between languages from one language family (exactly Russian and Ukrainian).

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='char_wb', max_features=100000, ngram_range=(1, 3),
#                 preprocessor=<function no_punctuation_preprocessor at 0x0000021314003BA0>)

# %% [markdown]
# As we can see, this TF-IDF implementation has been training for a pretty long time considering that we'll be tuning hyperparameters of both encoder and our classification model, so we're not likely to use it considering that it is also an offline implementation.

# %% [markdown]
# ## HashingVectorizer

# %% [markdown]
# HashingVectorizer is an online approach, which means that we can partially train it. Also, its scikit-learn implementation should be noticably faster than the implementation of TF-IDF (although it's resuls can be quite worse, but it's still faster to train which means that it's also faster to tune).

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1,3),
    n_features=2**20,
    lowercase=True,
    preprocessor=no_punctuation_preprocessor
)

# %%
vectorizer.fit_transform(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 172011046 stored elements and shape (2273614, 1048576)>

# %% [markdown]
# As this vectorizer is online, it's fit is stateless, but it's whole expensive computation is performed during transform stage. In result we can see, that it's still faster than TF-IDF, so we'll use it during our hyperparameters tuning.

# %% [markdown]
# # Models

# %% [markdown]
# We'll try two different models - SGDClassifier and Multinomial NaiveBayes, both of which are pretty popular in text classification tasks.
#
# We're not gonna try other popular models, such as XGBoost and LightGBM, in this specific case due to the fact that they are gonna consume a lot more memory (proportional to `amount of rows` * `amount of features`) and be much slower (time of execution is proportional to `amount of rows` * `amount of features` * `amount of trees (weak learners)`) than our two models of choice.

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
from utils.models.transformers import TextCleaner
from utils.models.language_detector import LanguageDetector

# %% [markdown]
# ## SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd_model_path = "models/dev/sgd_language_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def sgdclassifier_objective(trial: optuna.Trial):
    # TextCleaner hyperparameters
    text_cleaner_mode = trial.suggest_categorical("text_cleaner_mode", ["simple", "no_punct"])

    text_cleaner = TextCleaner(
        mode=text_cleaner_mode
    )

    # HashingVectorizer hyperparameters
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # SGDClassifier hyperparameters
    alpha = trial.suggest_float("alpha", 1e-6, 1e-2, log=True)
    penalty = trial.suggest_categorical("penalty", ["l2", "elasticnet"])

    # ElasticNet mixing parameter, will be ignored by model if penalty is l2
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    clf = SGDClassifier(
        loss='log_loss', # LogisticRegression
        penalty=penalty,
        alpha=alpha,
        l1_ratio=l1_ratio,
        class_weight="balanced", # Crutial because we have big class imbalance in our training dataset
        random_state=RANDOM_STATE,
        n_jobs=N_JOBS
    )

    pipeline = Pipeline([
        ("text_cleaner", text_cleaner),
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %% [markdown]
# Note that we skipped max_iter parameter because it does not impact partial_fit behaviour according to https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html.

# %%
study = optuna.create_study(direction="maximize")
study.optimize(sgdclassifier_objective, n_trials=40, show_progress_bar=True)
# Out:
# [I 2026-01-10 14:53:33,570] A new study created in memory with name: no-name-1ef9e02f-e06f-4e9a-97d0-94678ca9e258
#   0%|          | 0/40 [00:00<?, ?it/s]
# [I 2026-01-10 14:57:02,840] Trial 0 finished with value: 0.7938647093741019 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 4, 'alpha': 0.0014888865749667223, 'penalty': 'elasticnet', 'l1_ratio': 0.4347165985328806}. Best is trial 0 with value: 0.7938647093741019.
# [I 2026-01-10 15:01:01,043] Trial 1 finished with value: 0.9405647048186183 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 0.0003331759510744061, 'penalty': 'l2', 'l1_ratio': 0.27883155817525085}. Best is trial 1 with value: 0.9405647048186183.
# [I 2026-01-10 15:04:29,134] Trial 2 finished with value: 0.643681210053662 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 12, 'ngram_max': 5, 'alpha': 0.007410522819333763, 'penalty': 'l2', 'l1_ratio': 0.2950506998018063}. Best is trial 1 with value: 0.9405647048186183.
# [I 2026-01-10 15:08:35,232] Trial 3 finished with value: 0.9903990301412828 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 3.3063180250187788e-06, 'penalty': 'l2', 'l1_ratio': 0.7652465646575283}. Best is trial 3 with value: 0.9903990301412828.
# [I 2026-01-10 15:12:36,108] Trial 4 finished with value: 0.6687985005742688 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 4, 'alpha': 0.003978258614838125, 'penalty': 'elasticnet', 'l1_ratio': 0.2033755321882298}. Best is trial 3 with value: 0.9903990301412828.
# [I 2026-01-10 15:16:53,987] Trial 5 finished with value: 0.8302781322923577 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 12, 'ngram_max': 4, 'alpha': 0.0012319271734599474, 'penalty': 'elasticnet', 'l1_ratio': 0.057276440198309464}. Best is trial 3 with value: 0.9903990301412828.
# [I 2026-01-10 15:19:49,829] Trial 6 finished with value: 0.6504701840721158 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 3, 'alpha': 0.007005368064147176, 'penalty': 'elasticnet', 'l1_ratio': 0.527275587145815}. Best is trial 3 with value: 0.9903990301412828.
# [I 2026-01-10 15:24:10,500] Trial 7 finished with value: 0.9913200525417198 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 3.6556804699801406e-06, 'penalty': 'l2', 'l1_ratio': 0.6970717870015332}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:27:02,055] Trial 8 finished with value: 0.9900465362356305 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 3.5420300118687596e-06, 'penalty': 'l2', 'l1_ratio': 0.3459827157532509}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:30:46,303] Trial 9 finished with value: 0.800362609464214 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 5, 'alpha': 0.0018415119316816287, 'penalty': 'l2', 'l1_ratio': 0.3177612160747547}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:34:28,337] Trial 10 finished with value: 0.9831393123607133 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 2.8777579783209356e-05, 'penalty': 'l2', 'l1_ratio': 0.9601505328171872}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:37:52,641] Trial 11 finished with value: 0.9912163340972787 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 3, 'alpha': 1.0908818175578913e-06, 'penalty': 'l2', 'l1_ratio': 0.8015080299378261}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:40:32,194] Trial 12 finished with value: 0.9905629005928502 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 3, 'alpha': 1.5418391965570153e-06, 'penalty': 'l2', 'l1_ratio': 0.6810430084172302}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:43:52,768] Trial 13 finished with value: 0.9825284766601249 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 3, 'alpha': 1.400031027079231e-05, 'penalty': 'l2', 'l1_ratio': 0.853017090044313}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:47:03,185] Trial 14 finished with value: 0.9912305578597235 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 3, 'alpha': 1.137261521016319e-06, 'penalty': 'l2', 'l1_ratio': 0.6352368561237356}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:51:42,594] Trial 15 finished with value: 0.9868578960878723 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 1.4197767514045406e-05, 'penalty': 'l2', 'l1_ratio': 0.5963940378606932}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:55:23,740] Trial 16 finished with value: 0.973268432638526 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'alpha': 7.516473147535866e-05, 'penalty': 'l2', 'l1_ratio': 0.6373594738582272}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 15:59:02,456] Trial 17 finished with value: 0.9870951693472748 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 3, 'alpha': 5.2080252385426044e-06, 'penalty': 'l2', 'l1_ratio': 0.9135121492248619}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 16:02:22,575] Trial 18 finished with value: 0.9645876212519543 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 3, 'alpha': 0.00010409696947858704, 'penalty': 'elasticnet', 'l1_ratio': 0.710939617112742}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 16:06:12,208] Trial 19 finished with value: 0.9890120967024097 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 7.634377190713056e-06, 'penalty': 'l2', 'l1_ratio': 0.5149142329764766}. Best is trial 7 with value: 0.9913200525417198.
# [I 2026-01-10 16:09:14,934] Trial 20 finished with value: 0.9933225631019446 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 4, 'alpha': 1.0183235527116603e-06, 'penalty': 'l2', 'l1_ratio': 0.44093566768808584}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:13:07,503] Trial 21 finished with value: 0.9931556493706614 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 4, 'alpha': 1.110626214568394e-06, 'penalty': 'l2', 'l1_ratio': 0.4308238620126966}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:16:46,925] Trial 22 finished with value: 0.9914001729548461 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 4, 'alpha': 2.496117970165513e-06, 'penalty': 'l2', 'l1_ratio': 0.4586218028713227}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:20:59,175] Trial 23 finished with value: 0.9919580448429053 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 4, 'alpha': 2.000288221560139e-06, 'penalty': 'l2', 'l1_ratio': 0.4340226188327944}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:24:38,280] Trial 24 finished with value: 0.9872199443833812 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 9.02672598305719e-06, 'penalty': 'l2', 'l1_ratio': 0.1519674561575992}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:28:04,181] Trial 25 finished with value: 0.9918707413045394 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 4, 'alpha': 2.0697876706705155e-06, 'penalty': 'l2', 'l1_ratio': 0.41182785730786786}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:32:08,141] Trial 26 finished with value: 0.9736033754228856 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 4.195846137029989e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.5266608645375235}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:35:33,132] Trial 27 finished with value: 0.9929346887385105 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 1.1619759821300026e-06, 'penalty': 'l2', 'l1_ratio': 0.3868571167867185}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:39:11,917] Trial 28 finished with value: 0.9434661843276607 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 0.00030549322788788917, 'penalty': 'l2', 'l1_ratio': 0.2113752413977431}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:43:39,376] Trial 29 finished with value: 0.9925817660744635 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 1.153151692282475e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.37592367808315597}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:46:52,840] Trial 30 finished with value: 0.9884910032948312 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 6.508289217162984e-06, 'penalty': 'l2', 'l1_ratio': 0.002829415492790033}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:50:40,723] Trial 31 finished with value: 0.9922749895882289 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 1.3481063242800623e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.3858507905667167}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:54:04,932] Trial 32 finished with value: 0.9927654523805166 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 1.144374487889226e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.3695659260840315}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 16:58:30,975] Trial 33 finished with value: 0.9909613089103241 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 2.432670606091718e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.25437279027617066}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 17:02:16,950] Trial 34 finished with value: 0.9886559320062904 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 4, 'alpha': 4.534758430971768e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.46216049764302414}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 17:06:00,946] Trial 35 finished with value: 0.9930786997107207 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 1.0005552142422044e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.27085366830597607}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 17:09:43,359] Trial 36 finished with value: 0.9850591375045209 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 4, 'alpha': 1.2368818736716945e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.11421489204941848}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 17:13:36,687] Trial 37 finished with value: 0.9901006063383524 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 13, 'ngram_max': 4, 'alpha': 2.7059608981205254e-06, 'penalty': 'l2', 'l1_ratio': 0.30170900169463555}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 17:17:17,615] Trial 38 finished with value: 0.9424333446998691 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 4, 'alpha': 0.0002365367977071106, 'penalty': 'elasticnet', 'l1_ratio': 0.5762299705030567}. Best is trial 20 with value: 0.9933225631019446.
# [I 2026-01-10 17:20:38,852] Trial 39 finished with value: 0.980990655918376 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 2.7987010481334152e-05, 'penalty': 'l2', 'l1_ratio': 0.23889491032308172}. Best is trial 20 with value: 0.9933225631019446.

# %%
study.best_params
# Out:
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 17,
#  'ngram_max': 4,
#  'alpha': 1.0183235527116603e-06,
#  'penalty': 'l2',
#  'l1_ratio': 0.44093566768808584}

# %% [markdown]
# ```
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 17,
#  'ngram_max': 4,
#  'alpha': 1.0183235527116603e-06,
#  'penalty': 'l2',
#  'l1_ratio': 0.44093566768808584}
# ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters into a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
sgd_best_params = {
    'text_cleaner_mode': 'simple',
    'n_features_pow': 17,
    'ngram_max': 4,
    'alpha': 1.0183235527116603e-06,
    'penalty': 'l2',
    'l1_ratio': 0.44093566768808584
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    sgd_params = study.best_params
except:
    sgd_params = sgd_best_params

final_sgd_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, sgd_params["ngram_max"]),
    n_features=2 ** sgd_params["n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

final_sgd_clf = SGDClassifier(
    loss='log_loss',
    penalty=sgd_params["penalty"],
    alpha=sgd_params["alpha"],
    l1_ratio=sgd_params["l1_ratio"],
    class_weight="balanced",
    random_state=RANDOM_STATE,
    n_jobs=N_JOBS
)

final_sgd_pipeline = Pipeline([
    ("vectorizer", final_sgd_vectorizer),
    ("classifier", final_sgd_clf)
])

sgd_language_detector = LanguageDetector(final_sgd_pipeline)

# %%
sgd_language_detector.fit(X_train, y_train)
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(analyzer='char_wb',
#                                                         n_features=131072,
#                                                         ngram_range=(1, 4))),
#                                      ('classifier',
#                                       SGDClassifier(alpha=1.0183235527116603e-06,
#                                                     class_weight='balanced',
#                                                     l1_ratio=0.44093566768808584,
#                                                     loss='log_loss', n_jobs=6,
#                                                     random_state=0))]))

# %%
joblib.dump(sgd_language_detector, sgd_model_path)
# Out:
# ['models/dev/sgd_language_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
sgd_model = joblib.load(sgd_model_path)
sgd_model
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(analyzer='char_wb',
#                                                         n_features=131072,
#                                                         ngram_range=(1, 4))),
#                                      ('classifier',
#                                       SGDClassifier(alpha=1.0183235527116603e-06,
#                                                     class_weight='balanced',
#                                                     l1_ratio=0.44093566768808584,
#                                                     loss='log_loss', n_jobs=6,
#                                                     random_state=0))]))

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!

# %% [markdown]
# ## MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb_model_path = "models/dev/mnb_language_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def mnbclassifier_objective(trial: optuna.Trial):
    # TextCleaner hyperparameters
    text_cleaner_mode = trial.suggest_categorical("text_cleaner_mode", ["simple", "no_punct"])

    text_cleaner = TextCleaner(
        mode=text_cleaner_mode
    )

    # HashingVectorizer hyperparameters
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)
    vectorizer_norm = trial.suggest_categorical("vectorizer_norm", ["l2", None])

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        alternate_sign=False, # Values must be non-negative for MultinomialNB
        norm=vectorizer_norm,
        lowercase=True
    )

    # MultinomialNB hyperparameters
    alpha = trial.suggest_float("alpha", 1e-10, 10.0, log=True)
    fit_prior = trial.suggest_categorical("fit_prior", [True, False])

    clf = MultinomialNB(
        alpha=alpha,
        fit_prior=fit_prior
    )

    pipeline = Pipeline([
        ("text_cleaner", text_cleaner),
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(mnbclassifier_objective, n_trials=40, show_progress_bar=True)
# Out:
# [I 2026-01-10 17:24:04,499] A new study created in memory with name: no-name-65974d1b-b70a-4e2d-8c39-6b5b4f58d81f
#   0%|          | 0/40 [00:00<?, ?it/s]
# [I 2026-01-10 17:26:45,384] Trial 0 finished with value: 0.9925847080264205 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 15, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 0.0013874519058238214, 'fit_prior': False}. Best is trial 0 with value: 0.9925847080264205.
# [I 2026-01-10 17:29:44,170] Trial 1 finished with value: 0.9947457652899616 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 6.99446073251279e-06, 'fit_prior': True}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:33:22,695] Trial 2 finished with value: 0.9754688930088272 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 2.6842251463460354, 'fit_prior': True}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:36:08,352] Trial 3 finished with value: 0.9710091154809048 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 5.679316127640401e-09, 'fit_prior': True}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:40:11,061] Trial 4 finished with value: 0.9905350825980141 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 14, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 6.27939560953099e-08, 'fit_prior': True}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:42:57,214] Trial 5 finished with value: 0.9869821058401921 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 3, 'vectorizer_norm': None, 'alpha': 2.802948433180273, 'fit_prior': False}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:46:44,520] Trial 6 finished with value: 0.9913044427876679 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 14, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 0.7058956751793878, 'fit_prior': True}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:49:37,401] Trial 7 finished with value: 0.9747013413128697 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 5.269849178848367e-06, 'fit_prior': True}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:52:10,223] Trial 8 finished with value: 0.9874745707267437 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 13, 'ngram_max': 3, 'vectorizer_norm': None, 'alpha': 0.7048693638825264, 'fit_prior': True}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:54:57,594] Trial 9 finished with value: 0.9814292358426847 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 12, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 6.659539087198808e-08, 'fit_prior': False}. Best is trial 1 with value: 0.9947457652899616.
# [I 2026-01-10 17:57:58,290] Trial 10 finished with value: 0.995993756543713 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.00032287125998114796, 'fit_prior': False}. Best is trial 10 with value: 0.995993756543713.
# [I 2026-01-10 18:01:02,478] Trial 11 finished with value: 0.9960033604134374 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 5.503172880432489e-05, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:05:17,070] Trial 12 finished with value: 0.9959538437416656 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.0018424485307718592, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:08:29,823] Trial 13 finished with value: 0.9956311173777393 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.0008951413409213524, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:12:43,570] Trial 14 finished with value: 0.9951292548512765 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.00026780665321036887, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:16:02,663] Trial 15 finished with value: 0.9957745158329151 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.051854601446374195, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:19:18,994] Trial 16 finished with value: 0.9956161274672345 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 8.206034159296223e-07, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:22:35,497] Trial 17 finished with value: 0.9942494951393847 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 0.02707651919010126, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:26:48,479] Trial 18 finished with value: 0.9959319778440014 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 3.124459096004833e-05, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:30:03,499] Trial 19 finished with value: 0.9954781794367227 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 4.4059374697828103e-10, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:33:20,437] Trial 20 finished with value: 0.9958568587403592 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.00011424051778202172, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:37:02,171] Trial 21 finished with value: 0.9958908147934795 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.01027834780779934, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:40:18,528] Trial 22 finished with value: 0.9959540159102745 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.002358427459055812, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:43:35,329] Trial 23 finished with value: 0.9958577164205686 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 4.95853497282722e-05, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:47:18,426] Trial 24 finished with value: 0.9939694479542763 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 0.004671662454824345, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:51:02,548] Trial 25 finished with value: 0.9957014037851689 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.1250141227777338, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:55:15,360] Trial 26 finished with value: 0.9948891586513082 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 1.2957232207601874e-06, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 18:57:51,325] Trial 27 finished with value: 0.9944191445097581 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 0.0002603673754539993, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 19:01:11,530] Trial 28 finished with value: 0.9956484008669149 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 1.4015045754531327e-05, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 19:04:11,234] Trial 29 finished with value: 0.9936472985255919 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 0.0007798886377649196, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 19:07:46,229] Trial 30 finished with value: 0.9944524445757891 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 7.533156008131462e-07, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 19:10:56,845] Trial 31 finished with value: 0.9959463679773973 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.0035253714750083497, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 19:15:02,104] Trial 32 finished with value: 0.99582942166229 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.002260213702464752, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 19:18:13,275] Trial 33 finished with value: 0.9956528022191081 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.17415206075835604, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 19:22:34,720] Trial 34 finished with value: 0.9958511537387462 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.0004922344199757968, 'fit_prior': False}. Best is trial 11 with value: 0.9960033604134374.
# [I 2026-01-10 19:25:37,212] Trial 35 finished with value: 0.9960088032924793 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 9.474621440093196e-05, 'fit_prior': True}. Best is trial 35 with value: 0.9960088032924793.
# [I 2026-01-10 19:29:14,391] Trial 36 finished with value: 0.9957069785557247 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 3.7771779943408647e-06, 'fit_prior': True}. Best is trial 35 with value: 0.9960088032924793.
# [I 2026-01-10 19:32:52,470] Trial 37 finished with value: 0.9863699222747272 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 7.21425336000684e-05, 'fit_prior': True}. Best is trial 35 with value: 0.9960088032924793.
# [I 2026-01-10 19:36:33,242] Trial 38 finished with value: 0.9926386964512409 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 1.1189067549060543e-07, 'fit_prior': True}. Best is trial 35 with value: 0.9960088032924793.
# [I 2026-01-10 19:39:48,267] Trial 39 finished with value: 0.996035481666246 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 1.5770728751874113e-05, 'fit_prior': True}. Best is trial 39 with value: 0.996035481666246.

# %%
study.best_params
# Out:
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 20,
#  'ngram_max': 5,
#  'vectorizer_norm': 'l2',
#  'alpha': 1.5770728751874113e-05,
#  'fit_prior': True}

# %% [markdown]
# ```
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 20,
#  'ngram_max': 5,
#  'vectorizer_norm': 'l2',
#  'alpha': 1.5770728751874113e-05,
#  'fit_prior': True}
#  ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters to a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
mnb_best_params = {
    'text_cleaner_mode': 'simple',
    'n_features_pow': 20,
    'ngram_max': 5,
    'vectorizer_norm': 'l2',
    'alpha': 1.5770728751874113e-05,
    'fit_prior': True
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    mnb_params = study.best_params
except:
    mnb_params = mnb_best_params

final_mnb_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, mnb_params["ngram_max"]),
    n_features=2 ** mnb_params["n_features_pow"],
    alternate_sign=False,
    norm=mnb_params["vectorizer_norm"],
    lowercase=True
)

final_mnb_clf = MultinomialNB(
    alpha=mnb_params["alpha"],
    fit_prior=mnb_params["fit_prior"]
)

final_mnb_pipeline = Pipeline([
    ("vectorizer", final_mnb_vectorizer),
    ("classifier", final_mnb_clf)
])

mnb_language_detector = LanguageDetector(final_mnb_pipeline)

# %%
mnb_language_detector.fit(X_train, y_train)
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(alternate_sign=False,
#                                                         analyzer='char_wb',
#                                                         ngram_range=(1, 5))),
#                                      ('classifier',
#                                       MultinomialNB(alpha=1.5770728751874113e-05))]))

# %%
joblib.dump(mnb_language_detector, mnb_model_path)
# Out:
# ['models/dev/mnb_language_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
mnb_model = joblib.load(mnb_model_path)
mnb_model
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(alternate_sign=False,
#                                                         analyzer='char_wb',
#                                                         ngram_range=(1, 5))),
#                                      ('classifier',
#                                       MultinomialNB(alpha=1.5770728751874113e-05))]))

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!
