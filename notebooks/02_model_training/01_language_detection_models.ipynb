# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import optuna
import joblib

from typing import List
import string

# %%
RANDOM_STATE = 0
N_JOBS = 6

# %% [markdown]
# # Reading data

# %%
train_df = pd.read_csv("data/processed/train_language_detection_dataset.csv")
train_df.head()
# Out:
#                                             sentence lan_code
# 0                            Откуда ты о них знаешь?      rus
# 1  Tom persuaded his mother to lend him the car f...      eng
# 2                               Let's mop the floor.      eng
# 3  Tom leaves his dog in the house when he's at w...      eng
# 4                                 Они с ним любезны.      rus

# %%
X_train = train_df["sentence"]
y_train = train_df["lan_code"]

# %% [markdown]
# # Encoders

# %% [markdown]
# In this section we'll compare the learning speed of several different encoders for our texts as well as prepare different preprocessing approaches.

# %% [markdown]
# We should also note that all of our encoders are gonna tokenize text by characters and not by words for the reason that is we're trying to classify text and not to find some deep semantic meaning of it, for which separation by characters is a much better approach (it can handle typos and only "looks" for the character distribution by which language can be determined pretty accurately, but we still may be caring for characters order and for this reason we're gonna use custom n-grams parameter values).

# %% [markdown]
# ## Preprocessors

# %% [markdown]
# In this section we're gonna write some simple different preprocessors.

# %%
def simple_preprocessor(text: str) -> str:
    return text

# %%
def no_punctuation_preprocessor(text: str) -> str:
    blacklist_chars = string.punctuation
    translation_table = str.maketrans("", "", blacklist_chars)
    cleaned_text = text.translate(translation_table)
    return cleaned_text

# %%
preprocessors = {
    "simple": simple_preprocessor,
    "no_punct": no_punctuation_preprocessor
}

# %% [markdown]
# We're also gonna copy our preprocessor functions as a custom model to the file located at `../../app/models/transformers.py` in order to be able to use them from anywhere later without need to redefine them (and we also may need this for our final model to work properly).

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# scikin-learn's implementation of TF-IDF is offline, which means that it keeps everything in-memory and should be trained in one run. It may not be viable for training and tuning our models, but we still gonna check the perfomance of this approach as well.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer='char_wb', # We're caring only about characters in word bounds
    ngram_range=(1,3),
    max_features=100000,
    preprocessor=no_punctuation_preprocessor,
    lowercase=True,
)

# %% [markdown]
# Note that we're not using stopwords as they can be a crutial part in differentiating between languages from one language family (exactly Russian and Ukrainian).

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='char_wb', max_features=100000, ngram_range=(1, 3),
#                 preprocessor=<function no_punctuation_preprocessor at 0x0000021314003BA0>)

# %% [markdown]
# As we can see, this TF-IDF implementation has been training for a pretty long time considering that we'll be tuning hyperparameters of both encoder and our classification model, so we're not likely to use it considering that it is also an offline implementation.

# %% [markdown]
# ## HashingVectorizer

# %% [markdown]
# HashingVectorizer is an online approach, which means that we can partially train it. Also, its scikit-learn implementation should be noticably faster than the implementation of TF-IDF (although it's resuls can be quite worse, but it's still faster to train which means that it's also faster to tune).

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1,3),
    n_features=2**20,
    lowercase=True,
    preprocessor=no_punctuation_preprocessor
)

# %%
vectorizer.fit_transform(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 172011046 stored elements and shape (2273614, 1048576)>

# %% [markdown]
# As this vectorizer is online, it's fit is stateless, but it's whole expensive computation is performed during transform stage. In result we can see, that it's still faster than TF-IDF, so we'll use it during our hyperparameters tuning.

# %% [markdown]
# # Models

# %% [markdown]
# We'll try two different models - SGDClassifier and Multinomial NaiveBayes, both of which are pretty popular in text classification tasks.
#
# We're not gonna try other popular models, such as XGBoost and LightGBM, in this specific case due to the fact that they are gonna consume a lot more memory (proportional to `amount of rows` * `amount of features`) and be much slower (time of execution is proportional to `amount of rows` * `amount of features` * `amount of trees (weak learners)`) than our two models of choice.

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
from app.models.transformers import TextCleaner
from app.models.language_detector import LanguageDetector

# %% [markdown]
# ## SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd_model_path = "models/dev/sgd_language_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def sgdclassifier_objective(trial: optuna.Trial):
    # TextCleaner hyperparameters
    text_cleaner_mode = trial.suggest_categorical("text_cleaner_mode", ["simple", "no_punct"])

    text_cleaner = TextCleaner(
        mode=text_cleaner_mode
    )

    # HashingVectorizer hyperparameters
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # SGDClassifier hyperparameters
    alpha = trial.suggest_float("alpha", 1e-6, 1e-2, log=True)
    penalty = trial.suggest_categorical("penalty", ["l2", "elasticnet"])

    # ElasticNet mixing parameter, will be ignored by model if penalty is l2
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    clf = SGDClassifier(
        loss='log_loss', # LogisticRegression
        penalty=penalty,
        alpha=alpha,
        l1_ratio=l1_ratio,
        class_weight="balanced", # Crutial because we have big class imbalance in our training dataset
        random_state=RANDOM_STATE,
        n_jobs=N_JOBS
    )

    pipeline = Pipeline([
        ("text_cleaner", text_cleaner),
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %% [markdown]
# Note that we skipped max_iter parameter because it does not impact partial_fit behaviour according to https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html.

# %%
study = optuna.create_study(direction="maximize")
study.optimize(sgdclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-01-09 12:18:17,265] A new study created in memory with name: no-name-8b9e68a4-a53a-4731-b6a5-3923491bfa64
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-01-09 12:22:11,292] Trial 0 finished with value: 0.9916112985949885 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 3, 'alpha': 1.3040088308434453e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.9336832815420109}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:25:03,715] Trial 1 finished with value: 0.9641750135091555 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 3, 'alpha': 0.00010514659494314305, 'penalty': 'elasticnet', 'l1_ratio': 0.9693106169270105}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:29:14,870] Trial 2 finished with value: 0.7204133221691392 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 5, 'alpha': 0.004146288136286121, 'penalty': 'elasticnet', 'l1_ratio': 0.8503060397180782}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:32:37,155] Trial 3 finished with value: 0.9714882194288269 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 3, 'alpha': 7.035476851477073e-05, 'penalty': 'l2', 'l1_ratio': 0.08116697950289287}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:36:00,701] Trial 4 finished with value: 0.9826029492985988 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 13, 'ngram_max': 3, 'alpha': 1.3883134737648626e-05, 'penalty': 'l2', 'l1_ratio': 0.05933544825355386}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:39:28,933] Trial 5 finished with value: 0.9824858691289391 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 3, 'alpha': 1.4755224010518326e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.989734390138633}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:43:33,402] Trial 6 finished with value: 0.9842689166591562 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 1.9101928047378697e-05, 'penalty': 'l2', 'l1_ratio': 0.015816666251384226}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:46:49,717] Trial 7 finished with value: 0.9098094014057801 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 4, 'alpha': 0.0007000897506888397, 'penalty': 'l2', 'l1_ratio': 0.6377022096676667}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:50:14,563] Trial 8 finished with value: 0.9838687059656697 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 3, 'alpha': 1.2337962280984834e-05, 'penalty': 'l2', 'l1_ratio': 0.2918744943578655}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:53:43,711] Trial 9 finished with value: 0.9914396945949591 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 13, 'ngram_max': 4, 'alpha': 1.0479242596932426e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.9481798699746917}. Best is trial 0 with value: 0.9916112985949885.
# [I 2026-01-09 12:58:49,568] Trial 10 finished with value: 0.9922183469645732 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 1.5209640888148617e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.6399369528659711}. Best is trial 10 with value: 0.9922183469645732.
# [I 2026-01-09 13:04:26,707] Trial 11 finished with value: 0.9930461378314678 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 1.0876245813682907e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.6711307012729493}. Best is trial 11 with value: 0.9930461378314678.
# [I 2026-01-09 13:09:53,296] Trial 12 finished with value: 0.98920228987779 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 3.816024858474125e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.6901010551066851}. Best is trial 11 with value: 0.9930461378314678.
# [I 2026-01-09 13:15:23,575] Trial 13 finished with value: 0.9897928118538267 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 3.5273575650567173e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.47484905064580485}. Best is trial 11 with value: 0.9930461378314678.
# [I 2026-01-09 13:20:54,574] Trial 14 finished with value: 0.990590840307413 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 2.7631709277100065e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.4971129636451707}. Best is trial 11 with value: 0.9930461378314678.
# [I 2026-01-09 13:26:13,664] Trial 15 finished with value: 0.9633152137759415 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 9.243683943963249e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.7060176519525037}. Best is trial 11 with value: 0.9930461378314678.
# [I 2026-01-09 13:30:49,981] Trial 16 finished with value: 0.8900087218319569 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 4, 'alpha': 0.0006273955668869325, 'penalty': 'elasticnet', 'l1_ratio': 0.33809499177042324}. Best is trial 11 with value: 0.9930461378314678.
# [I 2026-01-09 13:35:29,317] Trial 17 finished with value: 0.9880169886163745 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'alpha': 5.094355535873912e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.7730622347066136}. Best is trial 11 with value: 0.9930461378314678.
# [I 2026-01-09 13:39:13,187] Trial 18 finished with value: 0.9905507580310782 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 12, 'ngram_max': 5, 'alpha': 1.1562320462339806e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.600160161576665}. Best is trial 11 with value: 0.9930461378314678.
# [I 2026-01-09 13:42:51,879] Trial 19 finished with value: 0.9755686775310474 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 4, 'alpha': 3.624041867364664e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.41885932320156494}. Best is trial 11 with value: 0.9930461378314678.

# %%
study.best_params
# Out:
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 20,
#  'ngram_max': 5,
#  'alpha': 1.0876245813682907e-06,
#  'penalty': 'elasticnet',
#  'l1_ratio': 0.6711307012729493}

# %% [markdown]
# ```
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 20,
#  'ngram_max': 5,
#  'alpha': 1.0876245813682907e-06,
#  'penalty': 'elasticnet',
#  'l1_ratio': 0.6711307012729493}
# ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters into a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
sgd_best_params = {
    'text_cleaner_mode': 'simple',
    'n_features_pow': 20,
    'ngram_max': 5,
    'alpha': 1.0876245813682907e-06,
    'penalty': 'elasticnet',
    'l1_ratio': 0.6711307012729493
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    xgb_params = study.best_params
except:
    xgb_params = sgd_best_params

final_sgd_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, xgb_params["ngram_max"]),
    n_features=2 ** xgb_params["n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

final_sgd_clf = SGDClassifier(
    loss='log_loss',
    penalty=xgb_params["penalty"],
    alpha=xgb_params["alpha"],
    l1_ratio=xgb_params["l1_ratio"],
    class_weight="balanced",
    random_state=RANDOM_STATE,
    n_jobs=N_JOBS
)

final_sgd_pipeline = Pipeline([
    ("vectorizer", final_sgd_vectorizer),
    ("classifier", final_sgd_clf)
])

sgd_language_detector = LanguageDetector(final_sgd_pipeline)

# %%
sgd_language_detector.fit(X_train, y_train)
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(analyzer='char_wb',
#                                                         ngram_range=(1, 5))),
#                                      ('classifier',
#                                       SGDClassifier(alpha=1.0876245813682907e-06,
#                                                     class_weight='balanced',
#                                                     l1_ratio=0.6711307012729493,
#                                                     loss='log_loss', n_jobs=6,
#                                                     penalty='elasticnet',
#                                                     random_state=0))]))

# %%
joblib.dump(sgd_language_detector, sgd_model_path)
# Out:
# ['models/dev/sgd_language_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
sgd_model = joblib.load(sgd_model_path)
sgd_model
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(analyzer='char_wb',
#                                                         ngram_range=(1, 5))),
#                                      ('classifier',
#                                       SGDClassifier(alpha=1.0876245813682907e-06,
#                                                     class_weight='balanced',
#                                                     l1_ratio=0.6711307012729493,
#                                                     loss='log_loss', n_jobs=6,
#                                                     penalty='elasticnet',
#                                                     random_state=0))]))

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!

# %% [markdown]
# ## MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb_model_path = "models/dev/mnb_language_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def mnbclassifier_objective(trial: optuna.Trial):
    # TextCleaner hyperparameters
    text_cleaner_mode = trial.suggest_categorical("text_cleaner_mode", ["simple", "no_punct"])

    text_cleaner = TextCleaner(
        mode=text_cleaner_mode
    )

    # HashingVectorizer hyperparameters
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)
    vectorizer_norm = trial.suggest_categorical("vectorizer_norm", ["l2", None])

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        alternate_sign=False, # Values must be non-negative for MultinomialNB
        norm=vectorizer_norm,
        lowercase=True
    )

    # MultinomialNB hyperparameters
    alpha = trial.suggest_float("alpha", 1e-10, 10.0, log=True)
    fit_prior = trial.suggest_categorical("fit_prior", [True, False])

    clf = MultinomialNB(
        alpha=alpha,
        fit_prior=fit_prior
    )

    pipeline = Pipeline([
        ("text_cleaner", text_cleaner),
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(mnbclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-01-09 22:05:57,451] A new study created in memory with name: no-name-bf9fa1a3-f24f-4a88-a50e-8f1f56914421
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-01-09 22:08:12,875] Trial 0 finished with value: 0.9891664943068297 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 2.9822796664741275e-09, 'fit_prior': False}. Best is trial 0 with value: 0.9891664943068297.
# [I 2026-01-09 22:11:21,172] Trial 1 finished with value: 0.986191300083899 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 1.0832963331907257e-07, 'fit_prior': True}. Best is trial 0 with value: 0.9891664943068297.
# [I 2026-01-09 22:14:25,910] Trial 2 finished with value: 0.9893298522284093 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 0.018168544263049022, 'fit_prior': False}. Best is trial 2 with value: 0.9893298522284093.
# [I 2026-01-09 22:17:44,811] Trial 3 finished with value: 0.9767096894270738 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 1.3007004469396864e-07, 'fit_prior': True}. Best is trial 2 with value: 0.9893298522284093.
# [I 2026-01-09 22:20:43,588] Trial 4 finished with value: 0.988864926482155 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 3, 'vectorizer_norm': None, 'alpha': 1.1339686412800571e-09, 'fit_prior': False}. Best is trial 2 with value: 0.9893298522284093.
# [I 2026-01-09 22:25:08,822] Trial 5 finished with value: 0.9935382730517467 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 0.0025545964743331536, 'fit_prior': True}. Best is trial 5 with value: 0.9935382730517467.
# [I 2026-01-09 22:28:56,119] Trial 6 finished with value: 0.996120167610223 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 4.411143858372626e-05, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 22:32:11,373] Trial 7 finished with value: 0.9924869933505195 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 0.000294448234213671, 'fit_prior': True}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 22:35:26,373] Trial 8 finished with value: 0.9903719390704455 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 14, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 4.172763883692821e-08, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 22:38:30,535] Trial 9 finished with value: 0.9378817000781897 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 12, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 2.0954232252316438e-07, 'fit_prior': True}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 22:42:12,154] Trial 10 finished with value: 0.9948882798189853 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 3.830248168888307, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 22:46:25,526] Trial 11 finished with value: 0.9952005848141661 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 3.4323980283772046, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 22:50:08,141] Trial 12 finished with value: 0.9893127768741764 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 8.471793219226326, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 22:53:47,571] Trial 13 finished with value: 0.9958570699260155 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 1.3614121311554056e-05, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 22:57:31,078] Trial 14 finished with value: 0.9960000339494898 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 1.153586227170533e-05, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 23:01:41,358] Trial 15 finished with value: 0.9958152458952249 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 9.015557647143053e-06, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 23:05:02,567] Trial 16 finished with value: 0.9944887662884149 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 0.05374223014543977, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 23:09:19,880] Trial 17 finished with value: 0.9958225189476169 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 2.9030050934897135e-06, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 23:12:38,157] Trial 18 finished with value: 0.98057579464054 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 12, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 0.0002141724536653176, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.
# [I 2026-01-09 23:16:50,124] Trial 19 finished with value: 0.9943810915088123 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 0.0001835934950182147, 'fit_prior': False}. Best is trial 6 with value: 0.996120167610223.

# %%
study.best_params
# Out:
# {'text_cleaner_mode': 'no_punct',
#  'n_features_pow': 20,
#  'ngram_max': 5,
#  'vectorizer_norm': 'l2',
#  'alpha': 4.411143858372626e-05,
#  'fit_prior': False}

# %% [markdown]
# ```
# {'text_cleaner_mode': 'no_punct',
#  'n_features_pow': 20,
#  'ngram_max': 5,
#  'vectorizer_norm': 'l2',
#  'alpha': 4.411143858372626e-05,
#  'fit_prior': False}
#  ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters to a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
mnb_best_params = {
    'text_cleaner_mode': 'no_punct',
    'n_features_pow': 20,
    'ngram_max': 5,
    'vectorizer_norm': 'l2',
    'alpha': 4.411143858372626e-05,
    'fit_prior': False
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `no_punct`, our model will lead best perfomance if we remove all the punctuation from the text before passing in to our model to identify its language.

# %%
try:
    xgb_params = study.best_params
except:
    xgb_params = mnb_best_params

final_mnb_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, xgb_params["ngram_max"]),
    n_features=2 ** xgb_params["n_features_pow"],
    alternate_sign=False,
    norm=xgb_params["vectorizer_norm"],
    lowercase=True
)

final_mnb_clf = MultinomialNB(
    alpha=xgb_params["alpha"],
    fit_prior=xgb_params["fit_prior"]
)

final_mnb_pipeline = Pipeline([
    ("vectorizer", final_mnb_vectorizer),
    ("classifier", final_mnb_clf)
])

mnb_language_detector = LanguageDetector(final_mnb_pipeline)

# %%
text_cleaner = TextCleaner(mode="no_punct")
X_train_cleaned = text_cleaner.fit_transform(X_train)
mnb_language_detector.fit(X_train_cleaned, y_train)
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(alternate_sign=False,
#                                                         analyzer='char_wb',
#                                                         ngram_range=(1, 5))),
#                                      ('classifier',
#                                       MultinomialNB(alpha=4.411143858372626e-05,
#                                                     fit_prior=False))]))

# %%
joblib.dump(mnb_language_detector, mnb_model_path)
# Out:
# ['models/dev/mnb_language_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
mnb_model = joblib.load(mnb_model_path)
mnb_model
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(alternate_sign=False,
#                                                         analyzer='char_wb',
#                                                         ngram_range=(1, 5))),
#                                      ('classifier',
#                                       MultinomialNB(alpha=4.411143858372626e-05,
#                                                     fit_prior=False))]))

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!
