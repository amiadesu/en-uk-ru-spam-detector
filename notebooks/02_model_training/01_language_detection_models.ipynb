# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import optuna
import joblib

from typing import List
import string

# %%
RANDOM_STATE = 0
N_JOBS = 6

# %%
import sys
import os

current_folder = os.path.abspath('') 

notebooks_folder = os.path.dirname(current_folder)

project_root = os.path.dirname(notebooks_folder)

if project_root not in sys.path:
    sys.path.append(project_root)

# %% [markdown]
# # Reading data

# %%
train_df = pd.read_csv("data/processed/train_language_detection_dataset.csv")
train_df.head()
# Out:
#                                             sentence lan_code
# 0                          Merry Christmas, Tatoeba!      eng
# 1         Крайне важно, чтобы мы поговорили с Томом.      rus
# 2                                   Она была весела.      rus
# 3  Urban sprawl is said to be a major contributor...      eng
# 4               Только не надо делать большие глаза.      rus

# %%
final_test_df = pd.read_csv("data/processed/test_language_detection_dataset.csv")
final_test_df.head()
# Out:
#                                             sentence lan_code
# 0                She suspected that it was too late.      eng
# 1                             Я порой бываю рассеян.      rus
# 2                                Он мог бы победить.      rus
# 3  Том мог быть не таким счастливым, каким прикид...      rus
# 4                  Do not forsake me, oh my darling.      eng

# %%
X_train = train_df["sentence"]
y_train = train_df["lan_code"]

# %%
X_final_test = final_test_df["sentence"]
y_final_test = final_test_df["lan_code"]

# %% [markdown]
# # Encoders

# %% [markdown]
# In this section we'll compare the learning speed of several different encoders for our texts as well as prepare different preprocessing approaches.

# %% [markdown]
# We should also note that all of our encoders are gonna tokenize text by characters and not by words for the reason that is we're trying to classify text and not to find some deep semantic meaning of it, for which separation by characters is a much better approach (it can handle typos and only "looks" for the character distribution by which language can be determined pretty accurately, but we still may be caring for characters order and for this reason we're gonna use custom n-grams parameter values).

# %% [markdown]
# ## Preprocessors

# %% [markdown]
# In this section we're gonna write some simple different preprocessors.

# %%
def simple_preprocessor(text: str) -> str:
    return text

# %%
def no_punctuation_preprocessor(text: str) -> str:
    blacklist_chars = string.punctuation
    translation_table = str.maketrans("", "", blacklist_chars)
    cleaned_text = text.translate(translation_table)
    return cleaned_text

# %%
preprocessors = {
    "simple": simple_preprocessor,
    "no_punct": no_punctuation_preprocessor
}

# %% [markdown]
# We're also gonna copy our preprocessor functions as a custom model to the file located at `../../app/models/transformers.py` in order to be able to use them from anywhere later without need to redefine them (and we also may need this for our final model to work properly).

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# scikin-learn's implementation of TF-IDF is offline, which means that it keeps everything in-memory and should be trained in one run. It may not be viable for training and tuning our models, but we still gonna check the perfomance of this approach as well.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer='char_wb', # We're caring only about characters in word bounds
    ngram_range=(1,3),
    max_features=100000,
    preprocessor=no_punctuation_preprocessor,
    lowercase=True,
)

# %% [markdown]
# Note that we're not using stopwords as they can be a crutial part in differentiating between languages from one language family (exactly Russian and Ukrainian).

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='char_wb', max_features=100000, ngram_range=(1, 3),
#                 preprocessor=<function no_punctuation_preprocessor at 0x0000021314003BA0>)

# %% [markdown]
# As we can see, this TF-IDF implementation has been training for a pretty long time considering that we'll be tuning hyperparameters of both encoder and our classification model, so we're not likely to use it considering that it is also an offline implementation.

# %% [markdown]
# ## HashingVectorizer

# %% [markdown]
# HashingVectorizer is an online approach, which means that we can partially train it. Also, its scikit-learn implementation should be noticably faster than the implementation of TF-IDF (although it's resuls can be quite worse, but it's still faster to train which means that it's also faster to tune).

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1,3),
    n_features=2**20,
    lowercase=True,
    preprocessor=no_punctuation_preprocessor
)

# %%
vectorizer.fit_transform(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 172011046 stored elements and shape (2273614, 1048576)>

# %% [markdown]
# As this vectorizer is online, it's fit is stateless, but it's whole expensive computation is performed during transform stage. In result we can see, that it's still faster than TF-IDF, so we'll use it during our hyperparameters tuning.

# %% [markdown]
# # Models

# %% [markdown]
# We'll try two different models - SGDClassifier and Multinomial NaiveBayes, both of which are pretty popular in text classification tasks.
#
# We're not gonna try other popular models, such as XGBoost and LightGBM, in this specific case due to the fact that they are gonna consume a lot more memory (proportional to `amount of rows` * `amount of features`) and be much slower (time of execution is proportional to `amount of rows` * `amount of features` * `amount of trees (weak learners)`) than our two models of choice.

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
from app.models.transformers import TextCleaner
from app.models.language_detector import LanguageDetector

# %% [markdown]
# ## SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd_model_path = "models/dev/sgd_language_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def sgdclassifier_objective(trial: optuna.Trial):
    # TextCleaner hyperparameters
    text_cleaner_mode = trial.suggest_categorical("text_cleaner_mode", ["simple", "no_punct"])

    text_cleaner = TextCleaner(
        mode=text_cleaner_mode
    )

    # HashingVectorizer hyperparameters
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # SGDClassifier hyperparameters
    alpha = trial.suggest_float("alpha", 1e-6, 1e-2, log=True)
    penalty = trial.suggest_categorical("penalty", ["l2", "elasticnet"])

    # ElasticNet mixing parameter, will be ignored by model if penalty is l2
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    clf = SGDClassifier(
        loss='log_loss', # LogisticRegression
        penalty=penalty,
        alpha=alpha,
        l1_ratio=l1_ratio,
        class_weight="balanced", # Crutial because we have big class imbalance in our training dataset
        random_state=RANDOM_STATE,
        n_jobs=N_JOBS
    )

    pipeline = Pipeline([
        ("text_cleaner", text_cleaner),
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %% [markdown]
# Note that we skipped max_iter parameter because it does not impact partial_fit behaviour according to https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html.

# %%
study = optuna.create_study(direction="maximize")
study.optimize(sgdclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-01-07 15:30:52,879] A new study created in memory with name: no-name-0c194e39-7133-4951-a66b-f6d0b6faacc1
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-01-07 15:35:45,680] Trial 0 finished with value: 0.6416253465489841 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 13, 'ngram_max': 5, 'alpha': 0.007111215148975124, 'penalty': 'elasticnet', 'l1_ratio': 0.048867313591985484}. Best is trial 0 with value: 0.6416253465489841.
# [I 2026-01-07 15:40:00,769] Trial 1 finished with value: 0.9500587582522858 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 13, 'ngram_max': 4, 'alpha': 0.00022691657594676922, 'penalty': 'elasticnet', 'l1_ratio': 0.8735592215668877}. Best is trial 1 with value: 0.9500587582522858.
# [I 2026-01-07 15:44:17,065] Trial 2 finished with value: 0.9760172285568324 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 3.8176992409193474e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.6088666619775157}. Best is trial 2 with value: 0.9760172285568324.
# [I 2026-01-07 15:47:53,714] Trial 3 finished with value: 0.9638567396190442 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 5, 'alpha': 9.432127801885823e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.8334562889555154}. Best is trial 2 with value: 0.9760172285568324.
# [I 2026-01-07 15:51:38,921] Trial 4 finished with value: 0.9890158545086812 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 12, 'ngram_max': 5, 'alpha': 3.017107091276563e-06, 'penalty': 'l2', 'l1_ratio': 0.14690860893484392}. Best is trial 4 with value: 0.9890158545086812.
# [I 2026-01-07 15:55:35,447] Trial 5 finished with value: 0.9164138742530538 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 5, 'alpha': 0.0006266705936097883, 'penalty': 'l2', 'l1_ratio': 0.7322373475702246}. Best is trial 4 with value: 0.9890158545086812.
# [I 2026-01-07 16:00:56,156] Trial 6 finished with value: 0.9535701197012774 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 0.00020932278763076474, 'penalty': 'elasticnet', 'l1_ratio': 0.9998508112796525}. Best is trial 4 with value: 0.9890158545086812.
# [I 2026-01-07 16:03:58,752] Trial 7 finished with value: 0.9793724414628838 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 3, 'alpha': 2.262771379343147e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.8994311557882054}. Best is trial 4 with value: 0.9890158545086812.
# [I 2026-01-07 16:07:45,416] Trial 8 finished with value: 0.9916524092488875 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 15, 'ngram_max': 5, 'alpha': 2.6104025365816045e-06, 'penalty': 'l2', 'l1_ratio': 0.9634570080437602}. Best is trial 8 with value: 0.9916524092488875.
# [I 2026-01-07 16:11:57,070] Trial 9 finished with value: 0.9671963383893177 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 0.0001351471115284153, 'penalty': 'l2', 'l1_ratio': 0.6889546233056714}. Best is trial 8 with value: 0.9916524092488875.
# [I 2026-01-07 16:14:46,046] Trial 10 finished with value: 0.9923409641919769 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 1.3790532708291383e-06, 'penalty': 'l2', 'l1_ratio': 0.41958951377112097}. Best is trial 10 with value: 0.9923409641919769.
# [I 2026-01-07 16:18:39,241] Trial 11 finished with value: 0.9917772773365948 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 1.7975307518195323e-06, 'penalty': 'l2', 'l1_ratio': 0.2873709361299299}. Best is trial 10 with value: 0.9923409641919769.
# [I 2026-01-07 16:22:13,555] Trial 12 finished with value: 0.9928886426829647 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 1.011712448172737e-06, 'penalty': 'l2', 'l1_ratio': 0.373624350566634}. Best is trial 12 with value: 0.9928886426829647.
# [I 2026-01-07 16:25:30,666] Trial 13 finished with value: 0.9841921094289189 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 3, 'alpha': 9.908340425244298e-06, 'penalty': 'l2', 'l1_ratio': 0.40007143642328097}. Best is trial 12 with value: 0.9928886426829647.
# [I 2026-01-07 16:29:15,751] Trial 14 finished with value: 0.9924392210697505 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 1.1634597720605713e-06, 'penalty': 'l2', 'l1_ratio': 0.4660571129398192}. Best is trial 12 with value: 0.9928886426829647.
# [I 2026-01-07 16:33:08,935] Trial 15 finished with value: 0.987554269245409 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 13, 'ngram_max': 4, 'alpha': 6.046939118551821e-06, 'penalty': 'l2', 'l1_ratio': 0.544633273926142}. Best is trial 12 with value: 0.9928886426829647.
# [I 2026-01-07 16:36:22,101] Trial 16 finished with value: 0.9912387681097431 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 3, 'alpha': 1.062377897655987e-06, 'penalty': 'l2', 'l1_ratio': 0.2391588590886235}. Best is trial 12 with value: 0.9928886426829647.
# [I 2026-01-07 16:40:14,050] Trial 17 finished with value: 0.986774220554314 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 9.008337794399383e-06, 'penalty': 'l2', 'l1_ratio': 0.4533777657401323}. Best is trial 12 with value: 0.9928886426829647.
# [I 2026-01-07 16:43:58,813] Trial 18 finished with value: 0.8835453203212537 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 0.0008967499964268755, 'penalty': 'l2', 'l1_ratio': 0.3208484078959421}. Best is trial 12 with value: 0.9928886426829647.
# [I 2026-01-07 16:47:57,814] Trial 19 finished with value: 0.9814068048749237 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 4, 'alpha': 2.6995675624163442e-05, 'penalty': 'l2', 'l1_ratio': 0.5436950815594501}. Best is trial 12 with value: 0.9928886426829647.

# %%
study.best_params
# Out:
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 15,
#  'ngram_max': 4,
#  'alpha': 1.011712448172737e-06,
#  'penalty': 'l2',
#  'l1_ratio': 0.373624350566634}

# %% [markdown]
# ```
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 15,
#  'ngram_max': 4,
#  'alpha': 1.011712448172737e-06,
#  'penalty': 'l2',
#  'l1_ratio': 0.373624350566634}
# ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters into a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
sgd_best_params = {
    'text_cleaner_mode': 'simple',
    'n_features_pow': 15,
    'ngram_max': 4,
    'alpha': 1.011712448172737e-06,
    'penalty': 'l2',
    'l1_ratio': 0.373624350566634
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    xgb_params = study.best_params
except:
    xgb_params = sgd_best_params

final_sgd_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, xgb_params["ngram_max"]),
    n_features=2 ** xgb_params["n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

final_sgd_clf = SGDClassifier(
    loss='log_loss',
    penalty=xgb_params["penalty"],
    alpha=xgb_params["alpha"],
    l1_ratio=xgb_params["l1_ratio"],
    class_weight="balanced",
    random_state=RANDOM_STATE,
    n_jobs=N_JOBS
)

final_sgd_pipeline = Pipeline([
    ("vectorizer", final_sgd_vectorizer),
    ("classifier", final_sgd_clf)
])

sgd_language_detector = LanguageDetector(final_sgd_pipeline)

# %%
sgd_language_detector.fit(X_train, y_train)
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(analyzer='char_wb',
#                                                         n_features=32768,
#                                                         ngram_range=(1, 4))),
#                                      ('classifier',
#                                       SGDClassifier(alpha=1.011712448172737e-06,
#                                                     class_weight='balanced',
#                                                     l1_ratio=0.373624350566634,
#                                                     loss='log_loss', n_jobs=6,
#                                                     random_state=0))]))

# %%
joblib.dump(sgd_language_detector, sgd_model_path)
# Out:
# ['models/dev/sgd_language_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
sgd_model = joblib.load(sgd_model_path)
sgd_model
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(analyzer='char_wb',
#                                                         n_features=32768,
#                                                         ngram_range=(1, 4))),
#                                      ('classifier',
#                                       SGDClassifier(alpha=1.011712448172737e-06,
#                                                     class_weight='balanced',
#                                                     l1_ratio=0.373624350566634,
#                                                     loss='log_loss', n_jobs=6,
#                                                     random_state=0))]))

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!

# %% [markdown]
# ## MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb_model_path = "models/dev/mnb_language_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def mnbclassifier_objective(trial: optuna.Trial):
    # TextCleaner hyperparameters
    text_cleaner_mode = trial.suggest_categorical("text_cleaner_mode", ["simple", "no_punct"])

    text_cleaner = TextCleaner(
        mode=text_cleaner_mode
    )

    # HashingVectorizer hyperparameters
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)
    vectorizer_norm = trial.suggest_categorical("vectorizer_norm", ["l2", None])

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        alternate_sign=False, # Values must be non-negative for MultinomialNB
        norm=vectorizer_norm,
        lowercase=True
    )

    # MultinomialNB hyperparameters
    alpha = trial.suggest_float("alpha", 1e-10, 10.0, log=True)
    fit_prior = trial.suggest_categorical("fit_prior", [True, False])

    clf = MultinomialNB(
        alpha=alpha,
        fit_prior=fit_prior
    )

    pipeline = Pipeline([
        ("text_cleaner", text_cleaner),
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(mnbclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-01-07 18:19:34,695] A new study created in memory with name: no-name-4010187c-4e22-43cc-b0dc-a108707b9980
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-01-07 18:21:45,203] Trial 0 finished with value: 0.9891935103412478 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 9.458303809457318e-06, 'fit_prior': False}. Best is trial 0 with value: 0.9891935103412478.
# [I 2026-01-07 18:24:33,131] Trial 1 finished with value: 0.9924869249683289 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 9.08413893385699e-06, 'fit_prior': True}. Best is trial 1 with value: 0.9924869249683289.
# [I 2026-01-07 18:27:27,950] Trial 2 finished with value: 0.9887192434414064 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 14, 'ngram_max': 3, 'vectorizer_norm': None, 'alpha': 0.028403104290041604, 'fit_prior': True}. Best is trial 1 with value: 0.9924869249683289.
# [I 2026-01-07 18:30:35,298] Trial 3 finished with value: 0.9896048877107709 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 2.144098714578102e-09, 'fit_prior': True}. Best is trial 1 with value: 0.9924869249683289.
# [I 2026-01-07 18:33:47,144] Trial 4 finished with value: 0.9955865930786348 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.002134692018632551, 'fit_prior': False}. Best is trial 4 with value: 0.9955865930786348.
# [I 2026-01-07 18:37:31,967] Trial 5 finished with value: 0.9901878449327781 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 14, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 1.3543944484357304e-08, 'fit_prior': False}. Best is trial 4 with value: 0.9955865930786348.
# [I 2026-01-07 18:41:01,302] Trial 6 finished with value: 0.9913619059940135 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 1.1250697268245051e-08, 'fit_prior': True}. Best is trial 4 with value: 0.9955865930786348.
# [I 2026-01-07 18:43:15,236] Trial 7 finished with value: 0.9889485747465994 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 3, 'vectorizer_norm': None, 'alpha': 0.0007400374616837199, 'fit_prior': False}. Best is trial 4 with value: 0.9955865930786348.
# [I 2026-01-07 18:46:31,179] Trial 8 finished with value: 0.9944622379675899 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 18, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 5.531827403991172e-06, 'fit_prior': False}. Best is trial 4 with value: 0.9955865930786348.
# [I 2026-01-07 18:50:08,717] Trial 9 finished with value: 0.9934277099154816 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 1.9680449971531452e-05, 'fit_prior': False}. Best is trial 4 with value: 0.9955865930786348.
# [I 2026-01-07 18:54:13,396] Trial 10 finished with value: 0.9956229266396736 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.1689687301815822, 'fit_prior': False}. Best is trial 10 with value: 0.9956229266396736.
# [I 2026-01-07 18:58:19,170] Trial 11 finished with value: 0.9956648180113268 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.10627389521048305, 'fit_prior': False}. Best is trial 11 with value: 0.9956648180113268.
# [I 2026-01-07 19:02:18,924] Trial 12 finished with value: 0.9932946791769336 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 5.8987557042541425, 'fit_prior': False}. Best is trial 11 with value: 0.9956648180113268.
# [I 2026-01-07 19:05:48,151] Trial 13 finished with value: 0.9890938809702351 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 9.088336684856394, 'fit_prior': False}. Best is trial 11 with value: 0.9956648180113268.
# [I 2026-01-07 19:09:36,705] Trial 14 finished with value: 0.9746314020879557 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 12, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.04232731166595331, 'fit_prior': False}. Best is trial 11 with value: 0.9956648180113268.
# [I 2026-01-07 19:13:33,669] Trial 15 finished with value: 0.9954751468305106 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.13302995881615146, 'fit_prior': False}. Best is trial 11 with value: 0.9956648180113268.
# [I 2026-01-07 19:16:30,886] Trial 16 finished with value: 0.9952166445867131 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.4349228956222306, 'fit_prior': False}. Best is trial 11 with value: 0.9956648180113268.
# [I 2026-01-07 19:19:57,849] Trial 17 finished with value: 0.994754496024321 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.0005723882504026871, 'fit_prior': False}. Best is trial 11 with value: 0.9956648180113268.
# [I 2026-01-07 19:23:46,117] Trial 18 finished with value: 0.9958612364280759 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 3.8254180916274174e-07, 'fit_prior': True}. Best is trial 18 with value: 0.9958612364280759.
# [I 2026-01-07 19:26:54,339] Trial 19 finished with value: 0.9946723186718822 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 6.077849259897315e-07, 'fit_prior': True}. Best is trial 18 with value: 0.9958612364280759.

# %%
study.best_params
# Out:
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 19,
#  'ngram_max': 5,
#  'vectorizer_norm': None,
#  'alpha': 3.8254180916274174e-07,
#  'fit_prior': True}

# %% [markdown]
# ```
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 19,
#  'ngram_max': 5,
#  'vectorizer_norm': None,
#  'alpha': 3.8254180916274174e-07,
#  'fit_prior': True}
#  ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters to a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
mnb_best_params = {
    'text_cleaner_mode': 'simple',
    'n_features_pow': 19,
    'ngram_max': 5,
    'vectorizer_norm': None,
    'alpha': 3.8254180916274174e-07,
    'fit_prior': True
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    xgb_params = study.best_params
except:
    xgb_params = mnb_best_params

final_mnb_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, xgb_params["ngram_max"]),
    n_features=2 ** xgb_params["n_features_pow"],
    alternate_sign=False,
    norm=xgb_params["vectorizer_norm"],
    lowercase=True
)

final_mnb_clf = MultinomialNB(
    alpha=xgb_params["alpha"],
    fit_prior=xgb_params["fit_prior"]
)

final_mnb_pipeline = Pipeline([
    ("vectorizer", final_mnb_vectorizer),
    ("classifier", final_mnb_clf)
])

mnb_language_detector = LanguageDetector(final_mnb_pipeline)

# %%
mnb_language_detector.fit(X_train, y_train)
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(alternate_sign=False,
#                                                         analyzer='char_wb',
#                                                         n_features=524288,
#                                                         ngram_range=(1, 5),
#                                                         norm=None)),
#                                      ('classifier',
#                                       MultinomialNB(alpha=3.8254180916274174e-07))]))

# %%
joblib.dump(mnb_language_detector, mnb_model_path)
# Out:
# ['models/dev/mnb_language_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
mnb_model = joblib.load(mnb_model_path)
mnb_model
# Out:
# LanguageDetector(clf=Pipeline(steps=[('vectorizer',
#                                       HashingVectorizer(alternate_sign=False,
#                                                         analyzer='char_wb',
#                                                         n_features=524288,
#                                                         ngram_range=(1, 5),
#                                                         norm=None)),
#                                      ('classifier',
#                                       MultinomialNB(alpha=3.8254180916274174e-07))]))

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!
