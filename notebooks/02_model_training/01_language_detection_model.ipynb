# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import optuna
import joblib

from typing import List
import string

# %%
RANDOM_STATE = 0
N_JOBS = 6

# %%
import sys
import os

current_folder = os.path.abspath('') 

notebooks_folder = os.path.dirname(current_folder)

project_root = os.path.dirname(notebooks_folder)

if project_root not in sys.path:
    sys.path.append(project_root)

# %% [markdown]
# # Reading data

# %%
train_df = pd.read_csv("../../data/processed/train_language_detection_dataset.csv")
train_df.head()
# Out:
#                                             sentence lan_code
# 0                          Merry Christmas, Tatoeba!      eng
# 1         Крайне важно, чтобы мы поговорили с Томом.      rus
# 2                                   Она была весела.      rus
# 3  Urban sprawl is said to be a major contributor...      eng
# 4               Только не надо делать большие глаза.      rus

# %%
final_test_df = pd.read_csv("../../data/processed/test_language_detection_dataset.csv")
final_test_df.head()
# Out:
#                                             sentence lan_code
# 0                She suspected that it was too late.      eng
# 1                             Я порой бываю рассеян.      rus
# 2                                Он мог бы победить.      rus
# 3  Том мог быть не таким счастливым, каким прикид...      rus
# 4                  Do not forsake me, oh my darling.      eng

# %%
X_train = train_df["sentence"]
y_train = train_df["lan_code"]

# %%
X_final_test = final_test_df["sentence"]
y_final_test = final_test_df["lan_code"]

# %% [markdown]
# # Encoders

# %% [markdown]
# In this section we'll compare the learning speed of several different encoders for our texts as well as prepare different preprocessing approaches.

# %% [markdown]
# We should also note that all of our encoders are gonna tokenize text by characters and not by words for the reason that is we're trying to classify text and not to find some deep semantic meaning of it, for which separation by characters is a much better approach (it can handle typos and only "looks" for the character distribution by which language can be determined pretty accurately, but we still may be caring for characters order and for this reason we're gonna use custom n-grams parameter values).

# %% [markdown]
# ## Preprocessors

# %% [markdown]
# In this section we're gonna write some simple different preprocessors.

# %%
def simple_preprocessor(text: str) -> str:
    return text

# %%
def no_punctuation_preprocessor(text: str) -> str:
    blacklist_chars = string.punctuation
    translation_table = str.maketrans("", "", blacklist_chars)
    cleaned_text = text.translate(translation_table)
    return cleaned_text

# %%
preprocessors = {
    "simple": simple_preprocessor,
    "no_punct": no_punctuation_preprocessor
}

# %% [markdown]
# We're also gonna copy our preprocessor functions as a custom model to the file located at `../../app/models/transformers.py` in order to be able to use them from anywhere later without need to redefine them (and we also may need this for our final model to work properly).

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# scikin-learn's implementation of TF-IDF is offline, which means that it keeps everything in-memory and should be trained in one run. It may not be viable for training and tuning our models, but we still gonna check the perfomance of this approach as well.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer='char_wb', # We're caring only about characters in word bounds
    ngram_range=(1,3),
    max_features=100000,
    preprocessor=no_punctuation_preprocessor,
    lowercase=True,
)

# %% [markdown]
# Note that we're not using stopwords as they can be a crutial part in differentiating between languages from one language family (exactly Russian and Ukrainian).

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='char_wb', max_features=100000, ngram_range=(1, 3),
#                 preprocessor=<function no_punctuation_preprocessor at 0x0000021314003BA0>)

# %% [markdown]
# As we can see, this TF-IDF implementation has been training for a pretty long time considering that we'll be tuning hyperparameters of both encoder and our classification model, so we're not likely to use it considering that it is also an offline implementation.

# %% [markdown]
# ## HashingVectorizer

# %% [markdown]
# HashingVectorizer is an online approach, which means that we can partially train it. Also, its scikit-learn implementation should be noticably faster than the implementation of TF-IDF (although it's resuls can be quite worse, but it's still faster to train which means that it's also faster to tune).

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1,3),
    n_features=2**20,
    lowercase=True,
    preprocessor=no_punctuation_preprocessor
)

# %%
vectorizer.fit_transform(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 172011046 stored elements and shape (2273614, 1048576)>

# %% [markdown]
# As this vectorizer is online, it's fit is stateless, but it's whole expensive computation is performed during transform stage. In result we can see, that it's still faster than TF-IDF, so we'll use it during our hyperparameters tuning.

# %% [markdown]
# # Models

# %% [markdown]
# We'll try three different models - SGDClassifier, Multinomial NaiveBayes and XGBoost, all of which are pretty popular in text classification tasks.

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
from app.models.transformers import TextCleaner

# %% [markdown]
# ## SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
sgd_model_path = "../../models/dev/sgd_language_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def sgdclassifier_objective(trial: optuna.Trial):
    # TextCleaner hyperparameters
    text_cleaner_mode = trial.suggest_categorical("text_cleaner_mode", ["simple", "no_punct"])

    text_cleaner = TextCleaner(
        mode=text_cleaner_mode
    )

    # HashingVectorizer hyperparameters
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # SGDClassifier hyperparameters
    alpha = trial.suggest_float("alpha", 1e-6, 1e-2, log=True)
    penalty = trial.suggest_categorical("penalty", ["l2", "elasticnet"])

    # ElasticNet mixing parameter, will be ignored by model if penalty is l2
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    clf = SGDClassifier(
        loss='log_loss', # LogisticRegression
        penalty=penalty,
        alpha=alpha,
        l1_ratio=l1_ratio,
        class_weight="balanced", # Crutial because we have big class imbalance in our training dataset
        random_state=RANDOM_STATE,
        n_jobs=N_JOBS
    )

    pipeline = Pipeline([
        ("text_cleaner", text_cleaner),
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    scores = cross_val_score(
        pipeline,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %% [markdown]
# Note that we skipped max_iter parameter because it does not impact partial_fit behaviour according to https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html.

# %%
study = optuna.create_study(direction="maximize")
study.optimize(sgdclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-01-06 13:43:46,778] A new study created in memory with name: no-name-c5388e98-9e9b-4efa-9263-8c4150b205fe
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-01-06 13:47:09,585] Trial 0 finished with value: 0.7825068112260452 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 13, 'ngram_max': 3, 'alpha': 0.0032034087882173833, 'penalty': 'elasticnet', 'l1_ratio': 0.9272854236095921}. Best is trial 0 with value: 0.7825068112260452.
# [I 2026-01-06 13:50:25,820] Trial 1 finished with value: 0.6490575977714391 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 3, 'alpha': 0.007978455193278595, 'penalty': 'elasticnet', 'l1_ratio': 0.6309709514070638}. Best is trial 0 with value: 0.7825068112260452.
# [I 2026-01-06 13:53:11,336] Trial 2 finished with value: 0.7791140345527499 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 3, 'alpha': 0.0022769798693948007, 'penalty': 'l2', 'l1_ratio': 0.48065368689884713}. Best is trial 0 with value: 0.7825068112260452.
# [I 2026-01-06 13:56:18,171] Trial 3 finished with value: 0.9845540476698081 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 1.5614699486830633e-05, 'penalty': 'l2', 'l1_ratio': 0.18713743141303785}. Best is trial 3 with value: 0.9845540476698081.
# [I 2026-01-06 13:59:20,137] Trial 4 finished with value: 0.9774681279082648 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 3, 'alpha': 3.5015191716347275e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.9384926398478116}. Best is trial 3 with value: 0.9845540476698081.
# [I 2026-01-06 14:03:46,439] Trial 5 finished with value: 0.9822103011973383 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 17, 'ngram_max': 5, 'alpha': 1.6842687947191254e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.7827746189765198}. Best is trial 3 with value: 0.9845540476698081.
# [I 2026-01-06 14:08:01,011] Trial 6 finished with value: 0.9879645818907742 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 5.5609701756828565e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.8357295753709028}. Best is trial 6 with value: 0.9879645818907742.
# [I 2026-01-06 14:11:38,684] Trial 7 finished with value: 0.939336262973632 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 13, 'ngram_max': 3, 'alpha': 0.00036282359414278637, 'penalty': 'l2', 'l1_ratio': 0.6335272769610791}. Best is trial 6 with value: 0.9879645818907742.
# [I 2026-01-06 14:15:02,127] Trial 8 finished with value: 0.991319069255043 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 1.8367371583487572e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.5743744677713999}. Best is trial 8 with value: 0.991319069255043.
# [I 2026-01-06 14:18:26,813] Trial 9 finished with value: 0.6413647139691977 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 4, 'alpha': 0.00893754401044789, 'penalty': 'l2', 'l1_ratio': 0.366657833214467}. Best is trial 8 with value: 0.991319069255043.
# [I 2026-01-06 14:21:48,421] Trial 10 finished with value: 0.9900999441767829 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 12, 'ngram_max': 4, 'alpha': 1.4101344712271332e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.03235837336284941}. Best is trial 8 with value: 0.991319069255043.
# [I 2026-01-06 14:25:02,377] Trial 11 finished with value: 0.9901888035578259 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 12, 'ngram_max': 4, 'alpha': 1.3700171734595778e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.05755059578337396}. Best is trial 8 with value: 0.991319069255043.
# [I 2026-01-06 14:28:21,893] Trial 12 finished with value: 0.9916553228816097 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 1.620831059912481e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.287618330400531}. Best is trial 12 with value: 0.9916553228816097.
# [I 2026-01-06 14:33:16,112] Trial 13 finished with value: 0.9515787647030671 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 5, 'alpha': 0.00017342230732007505, 'penalty': 'elasticnet', 'l1_ratio': 0.31088375537662377}. Best is trial 12 with value: 0.9916553228816097.
# [I 2026-01-06 14:36:47,338] Trial 14 finished with value: 0.9885323297428655 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 4.510922980972952e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.5058458066202366}. Best is trial 12 with value: 0.9916553228816097.
# [I 2026-01-06 14:41:03,648] Trial 15 finished with value: 0.9889199125245286 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 4.369894948979792e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.2422862102104178}. Best is trial 12 with value: 0.9916553228816097.
# [I 2026-01-06 14:44:50,110] Trial 16 finished with value: 0.9925401939601862 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 1.1179323625363607e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.4518974786326927}. Best is trial 16 with value: 0.9925401939601862.
# [I 2026-01-06 14:48:28,555] Trial 17 finished with value: 0.9710825337548797 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 5, 'alpha': 5.4954534896199215e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.40892000187219646}. Best is trial 16 with value: 0.9925401939601862.
# [I 2026-01-06 14:52:04,331] Trial 18 finished with value: 0.9277148523059232 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 5, 'alpha': 0.0004651077429381395, 'penalty': 'l2', 'l1_ratio': 0.173892200181323}. Best is trial 16 with value: 0.9925401939601862.
# [I 2026-01-06 14:55:31,394] Trial 19 finished with value: 0.9855799217487338 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 9.502729517500104e-06, 'penalty': 'elasticnet', 'l1_ratio': 0.2853707952659337}. Best is trial 16 with value: 0.9925401939601862.

# %%
study.best_params
# Out:
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 15,
#  'ngram_max': 4,
#  'alpha': 1.1179323625363607e-06,
#  'penalty': 'elasticnet',
#  'l1_ratio': 0.4518974786326927}

# %% [markdown]
# ```
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 15,
#  'ngram_max': 4,
#  'alpha': 1.1179323625363607e-06,
#  'penalty': 'elasticnet',
#  'l1_ratio': 0.4518974786326927}
# ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters into a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
sgd_best_params = {
    'text_cleaner_mode': 'simple',
    'n_features_pow': 15,
    'ngram_max': 4,
    'alpha': 1.1179323625363607e-06,
    'penalty': 'elasticnet',
    'l1_ratio': 0.4518974786326927
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    params = study.best_params
except:
    params = sgd_best_params

final_sgd_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, params["ngram_max"]),
    n_features=2 ** params["n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

final_sgd_clf = SGDClassifier(
    loss='log_loss',
    penalty=params["penalty"],
    alpha=params["alpha"],
    l1_ratio=params["l1_ratio"],
    class_weight="balanced",
    random_state=RANDOM_STATE,
    n_jobs=N_JOBS
)

final_sgd_pipeline = Pipeline([
    ("vectorizer", final_sgd_vectorizer),
    ("classifier", final_sgd_clf)
])

# %%
final_sgd_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer',
#                  HashingVectorizer(analyzer='char_wb', n_features=32768,
#                                    ngram_range=(1, 4))),
#                 ('classifier',
#                  SGDClassifier(alpha=1.1179323625363607e-06,
#                                class_weight='balanced',
#                                l1_ratio=0.4518974786326927, loss='log_loss',
#                                n_jobs=6, penalty='elasticnet',
#                                random_state=0))])

# %%
joblib.dump(final_sgd_pipeline, sgd_model_path)
# Out:
# ['../../models/dev/sgd_language_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
sgd_model = joblib.load(sgd_model_path)
sgd_model
# Out:
# Pipeline(steps=[('vectorizer',
#                  HashingVectorizer(analyzer='char_wb', n_features=32768,
#                                    ngram_range=(1, 4))),
#                 ('classifier',
#                  SGDClassifier(alpha=1.1179323625363607e-06,
#                                class_weight='balanced',
#                                l1_ratio=0.4518974786326927, loss='log_loss',
#                                n_jobs=6, penalty='elasticnet',
#                                random_state=0))])

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!

# %% [markdown]
# ## MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
mnb_model_path = "../../models/dev/mnb_language_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def sgdclassifier_objective(trial: optuna.Trial):
    # TextCleaner hyperparameters
    text_cleaner_mode = trial.suggest_categorical("text_cleaner_mode", ["simple", "no_punct"])

    text_cleaner = TextCleaner(
        mode=text_cleaner_mode
    )

    # HashingVectorizer hyperparameters
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)
    vectorizer_norm = trial.suggest_categorical("vectorizer_norm", ["l2", None])

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        alternate_sign=False, # Values must be non-negative for MultinomialNB
        norm=vectorizer_norm,
        lowercase=True
    )

    # MultinomialNB hyperparameters
    alpha = trial.suggest_float("alpha", 1e-10, 10.0, log=True)
    fit_prior = trial.suggest_categorical("fit_prior", [True, False])

    clf = MultinomialNB(
        alpha=alpha,
        fit_prior=fit_prior
    )

    pipeline = Pipeline([
        ("text_cleaner", text_cleaner),
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    scores = cross_val_score(
        pipeline,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(sgdclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-01-06 15:04:56,770] A new study created in memory with name: no-name-c04703a1-67e4-4848-982d-bb1e7add2106
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-01-06 15:07:20,542] Trial 0 finished with value: 0.9895692914602493 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 0.0019069600154671383, 'fit_prior': False}. Best is trial 0 with value: 0.9895692914602493.
# [I 2026-01-06 15:09:53,948] Trial 1 finished with value: 0.9828492028356766 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 12, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 9.044882026469729e-10, 'fit_prior': False}. Best is trial 0 with value: 0.9895692914602493.
# [I 2026-01-06 15:12:48,900] Trial 2 finished with value: 0.9936525177018432 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 2.6870705572275184e-09, 'fit_prior': False}. Best is trial 2 with value: 0.9936525177018432.
# [I 2026-01-06 15:16:09,882] Trial 3 finished with value: 0.9889555688910273 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 3, 'vectorizer_norm': 'l2', 'alpha': 3.684892774852724e-07, 'fit_prior': False}. Best is trial 2 with value: 0.9936525177018432.
# [I 2026-01-06 15:20:06,692] Trial 4 finished with value: 0.9858586895643885 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 14, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 7.744211203718494, 'fit_prior': False}. Best is trial 2 with value: 0.9936525177018432.
# [I 2026-01-06 15:23:56,664] Trial 5 finished with value: 0.9953630793590991 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 1.555031346334377e-05, 'fit_prior': False}. Best is trial 5 with value: 0.9953630793590991.
# [I 2026-01-06 15:26:57,168] Trial 6 finished with value: 0.9270884575469704 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 12, 'ngram_max': 5, 'vectorizer_norm': 'l2', 'alpha': 7.369899543366212e-06, 'fit_prior': True}. Best is trial 5 with value: 0.9953630793590991.
# [I 2026-01-06 15:30:46,022] Trial 7 finished with value: 0.9945825521213751 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 19, 'ngram_max': 4, 'vectorizer_norm': 'l2', 'alpha': 4.101241430209235e-08, 'fit_prior': False}. Best is trial 5 with value: 0.9953630793590991.
# [I 2026-01-06 15:33:58,788] Trial 8 finished with value: 0.9886900092633665 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 14, 'ngram_max': 3, 'vectorizer_norm': None, 'alpha': 1.367709568568675e-08, 'fit_prior': True}. Best is trial 5 with value: 0.9953630793590991.
# [I 2026-01-06 15:37:11,155] Trial 9 finished with value: 0.9896495145398917 and parameters: {'text_cleaner_mode': 'no_punct', 'n_features_pow': 16, 'ngram_max': 3, 'vectorizer_norm': None, 'alpha': 2.1228169560039256e-09, 'fit_prior': True}. Best is trial 5 with value: 0.9953630793590991.
# [I 2026-01-06 15:40:28,567] Trial 10 finished with value: 0.9956534091248952 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.002720128135713263, 'fit_prior': True}. Best is trial 10 with value: 0.9956534091248952.
# [I 2026-01-06 15:43:58,704] Trial 11 finished with value: 0.9956523371125318 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.003898739800121096, 'fit_prior': True}. Best is trial 10 with value: 0.9956534091248952.
# [I 2026-01-06 15:47:17,693] Trial 12 finished with value: 0.9956234382214028 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.01657283001199102, 'fit_prior': True}. Best is trial 10 with value: 0.9956534091248952.
# [I 2026-01-06 15:50:30,784] Trial 13 finished with value: 0.9945290149777186 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 18, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 0.006238349005423934, 'fit_prior': True}. Best is trial 10 with value: 0.9956534091248952.
# [I 2026-01-06 15:53:40,650] Trial 14 finished with value: 0.9957851714840639 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.8875841650707424, 'fit_prior': True}. Best is trial 14 with value: 0.9957851714840639.
# [I 2026-01-06 15:57:05,221] Trial 15 finished with value: 0.9927833889510201 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 5.917639190314591, 'fit_prior': True}. Best is trial 14 with value: 0.9957851714840639.
# [I 2026-01-06 16:00:12,677] Trial 16 finished with value: 0.9946820270396715 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 20, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 0.16568859459910565, 'fit_prior': True}. Best is trial 14 with value: 0.9957851714840639.
# [I 2026-01-06 16:03:00,162] Trial 17 finished with value: 0.994015658299814 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 17, 'ngram_max': 4, 'vectorizer_norm': None, 'alpha': 0.2711821797092639, 'fit_prior': True}. Best is trial 14 with value: 0.9957851714840639.
# [I 2026-01-06 16:06:40,856] Trial 18 finished with value: 0.9959823453434198 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 0.00022553046850033962, 'fit_prior': True}. Best is trial 18 with value: 0.9959823453434198.
# [I 2026-01-06 16:09:51,395] Trial 19 finished with value: 0.9959720944867034 and parameters: {'text_cleaner_mode': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'vectorizer_norm': None, 'alpha': 6.704361676325576e-05, 'fit_prior': True}. Best is trial 18 with value: 0.9959823453434198.

# %%
study.best_params
# Out:
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 19,
#  'ngram_max': 5,
#  'vectorizer_norm': None,
#  'alpha': 0.00022553046850033962,
#  'fit_prior': True}

# %% [markdown]
# ```
# {'text_cleaner_mode': 'simple',
#  'n_features_pow': 19,
#  'ngram_max': 5,
#  'vectorizer_norm': None,
#  'alpha': 0.00022553046850033962,
#  'fit_prior': True}
#  ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters to a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
mnb_best_params = {
    'text_cleaner_mode': 'simple',
    'n_features_pow': 19,
    'ngram_max': 5,
    'vectorizer_norm': None,
    'alpha': 0.00022553046850033962,
    'fit_prior': True
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    params = study.best_params
except:
    params = mnb_best_params

final_mnb_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, params["ngram_max"]),
    n_features=2 ** params["n_features_pow"],
    alternate_sign=False,
    norm=params["vectorizer_norm"],
    lowercase=True
)

final_mnb_clf = MultinomialNB(
    alpha=params["alpha"],
    fit_prior=params["fit_prior"]
)

final_mnb_pipeline = Pipeline([
    ("vectorizer", final_mnb_vectorizer),
    ("classifier", final_mnb_clf)
])

# %%
final_mnb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer',
#                  HashingVectorizer(alternate_sign=False, analyzer='char_wb',
#                                    n_features=524288, ngram_range=(1, 5),
#                                    norm=None)),
#                 ('classifier', MultinomialNB(alpha=0.00022553046850033962))])

# %%
joblib.dump(final_mnb_pipeline, mnb_model_path)
# Out:
# ['../../models/dev/mnb_language_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
mnb_model = joblib.load(mnb_model_path)
mnb_model
# Out:
# Pipeline(steps=[('vectorizer',
#                  HashingVectorizer(alternate_sign=False, analyzer='char_wb',
#                                    n_features=524288, ngram_range=(1, 5),
#                                    norm=None)),
#                 ('classifier', MultinomialNB(alpha=0.00022553046850033962))])

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!
