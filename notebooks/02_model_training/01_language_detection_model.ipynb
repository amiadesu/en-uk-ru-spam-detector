# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import optuna
import joblib

from typing import List
import string

# %%
RANDOM_STATE = 0
N_JOBS = 6

# %% [markdown]
# # Reading data

# %%
train_df = pd.read_csv("../../data/processed/train_language_detection_dataset.csv")
train_df.head()
# Out:
#                                             sentence lan_code
# 0                          Merry Christmas, Tatoeba!      eng
# 1         Крайне важно, чтобы мы поговорили с Томом.      rus
# 2                                   Она была весела.      rus
# 3  Urban sprawl is said to be a major contributor...      eng
# 4               Только не надо делать большие глаза.      rus

# %%
final_test_df = pd.read_csv("../../data/processed/test_language_detection_dataset.csv")
final_test_df.head()
# Out:
#                                             sentence lan_code
# 0                She suspected that it was too late.      eng
# 1                             Я порой бываю рассеян.      rus
# 2                                Он мог бы победить.      rus
# 3  Том мог быть не таким счастливым, каким прикид...      rus
# 4                  Do not forsake me, oh my darling.      eng

# %%
X_train = train_df["sentence"]
y_train = train_df["lan_code"]

# %%
X_final_test = final_test_df["sentence"]
y_final_test = final_test_df["lan_code"]

# %% [markdown]
# # Encoders

# %% [markdown]
# In this section we'll compare the learning speed of several different encoders for our texts as well as prepare different preprocessing approaches.

# %% [markdown]
# We should also note that all of our encoders are gonna tokenize text by characters and not by words for the reason that is we're trying to classify text and not to find some deep semantic meaning of it, for which separation by characters is a much better approach (it can handle typos and only "looks" for the character distribution by which language can be determined pretty accurately, but we still may be caring for characters order and for this reason we're gonna use custom n-grams parameter values).

# %% [markdown]
# ## Preprocessors

# %% [markdown]
# In this section we're gonna write some simple different preprocessors.

# %%
def simple_preprocessor(text: str) -> str:
    return text

# %%
def no_punctuation_preprocessor(text: str) -> str:
    blacklist_chars = string.punctuation
    translation_table = str.maketrans("", "", blacklist_chars)
    cleaned_text = text.translate(translation_table)
    return cleaned_text

# %%
preprocessors = {
    "simple": simple_preprocessor,
    "no_punct": no_punctuation_preprocessor
}

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# scikin-learn's implementation of TF-IDF is offline, which means that it keeps everything in-memory and should be trained in one run. It may not be viable for training and tuning our models, but we still gonna check the perfomance of this approach as well.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer='char_wb', # We're caring only about characters in word bounds
    ngram_range=(1,3),
    max_features=100000,
    preprocessor=no_punctuation_preprocessor,
    lowercase=True,
)

# %% [markdown]
# Note that we're not using stopwords as they can be a crutial part in differentiating between languages from one language family (exactly Russian and Ukrainian).

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='char_wb', max_features=100000, ngram_range=(1, 3),
#                 preprocessor=<function no_punctuation_preprocessor at 0x0000021314003BA0>)

# %% [markdown]
# As we can see, this TF-IDF implementation has been training for a pretty long time considering that we'll be tuning hyperparameters of both encoder and our classification model, so we're not likely to use it considering that it is also an offline implementation.

# %% [markdown]
# ## HashingVectorizer

# %% [markdown]
# HashingVectorizer is an online approach, which means that we can partially train it. Also, its scikit-learn implementation should be noticably faster than the implementation of TF-IDF (although it's resuls can be quite worse, but it's still faster to train which means that it's also faster to tune).

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1,3),
    n_features=2**20,
    lowercase=True,
    preprocessor=no_punctuation_preprocessor
)

# %%
vectorizer.fit_transform(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 172011046 stored elements and shape (2273614, 1048576)>

# %% [markdown]
# As this vectorizer is online, it's fit is stateless, but it's whole expensive computation is performed during transform stage. In result we can see, that it's still faster than TF-IDF, so we'll use it during our hyperparameters tuning.

# %% [markdown]
# # Models

# %% [markdown]
# We'll try three different models - SGDClassifier, Multinomial NaiveBayes and XGBoost, all of which are pretty popular in text classification tasks.

# %% [markdown]
# ## SGDClassifier

# %% [markdown]
# ### Tuning

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
def sgdclassifier_objective(trial: optuna.Trial):
    # HashingVectorizer hyperparameters
    prep_name = trial.suggest_categorical("preprocessor", list(preprocessors.keys()))
    preprocessor = preprocessors[prep_name]
    n_features_pow = trial.suggest_int("n_features_pow", 12, 20)
    ngram_max = trial.suggest_int("ngram_max", 3, 5)

    vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(1, ngram_max),
        n_features=2 ** n_features_pow,
        preprocessor=preprocessor,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # SGDClassifier hyperparameters
    alpha = trial.suggest_float("alpha", 1e-6, 1e-2, log=True)
    penalty = trial.suggest_categorical("penalty", ["l2", "elasticnet"])

    # ElasticNet mixing parameter, will be ignored by model if penalty is l2
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    clf = SGDClassifier(
        loss='log_loss', # LogisticRegression
        penalty=penalty,
        alpha=alpha,
        l1_ratio=l1_ratio,
        class_weight="balanced", # Crutial because we have big class imbalance in our training dataset
        random_state=RANDOM_STATE,
        n_jobs=N_JOBS
    )

    pipeline = Pipeline([
        ("vectorizer", vectorizer),
        ("classifier", clf)
    ])

    scores = cross_val_score(
        pipeline,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %% [markdown]
# Note that we skipped max_iter parameter because it does not impact partial_fit behaviour according to https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html.

# %%
study = optuna.create_study(direction="maximize")
study.optimize(sgdclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-01-04 15:26:07,774] A new study created in memory with name: no-name-0fb626e2-c2ea-4449-ac44-383fc1c84515
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-01-04 15:30:17,053] Trial 0 finished with value: 0.9854867955423026 and parameters: {'preprocessor': 'no_punct', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 8.298039111679069e-06, 'penalty': 'elasticnet', 'max_iter': 1697, 'l1_ratio': 0.1944574548372231}. Best is trial 0 with value: 0.9854867955423026.
# [I 2026-01-04 15:34:40,770] Trial 1 finished with value: 0.9913250314610041 and parameters: {'preprocessor': 'simple', 'n_features_pow': 19, 'ngram_max': 4, 'alpha': 2.325802351912329e-06, 'penalty': 'elasticnet', 'max_iter': 1997, 'l1_ratio': 0.03514745774727046}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 15:38:41,243] Trial 2 finished with value: 0.9773485365091737 and parameters: {'preprocessor': 'simple', 'n_features_pow': 12, 'ngram_max': 4, 'alpha': 2.325104182041563e-05, 'penalty': 'l2', 'max_iter': 687, 'l1_ratio': 0.8228819174630395}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 15:43:41,091] Trial 3 finished with value: 0.9636040206211102 and parameters: {'preprocessor': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 7.243574060027679e-05, 'penalty': 'elasticnet', 'max_iter': 1497, 'l1_ratio': 0.6702457118372609}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 15:47:17,988] Trial 4 finished with value: 0.8649381110267457 and parameters: {'preprocessor': 'no_punct', 'n_features_pow': 16, 'ngram_max': 3, 'alpha': 0.0009811761576485956, 'penalty': 'elasticnet', 'max_iter': 1937, 'l1_ratio': 0.5478449514936055}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 15:51:33,297] Trial 5 finished with value: 0.9740593446868034 and parameters: {'preprocessor': 'no_punct', 'n_features_pow': 15, 'ngram_max': 4, 'alpha': 5.204009375171395e-05, 'penalty': 'l2', 'max_iter': 714, 'l1_ratio': 0.06677983875859395}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 15:55:01,126] Trial 6 finished with value: 0.9720369393626583 and parameters: {'preprocessor': 'simple', 'n_features_pow': 13, 'ngram_max': 4, 'alpha': 4.8266452112370594e-05, 'penalty': 'l2', 'max_iter': 564, 'l1_ratio': 0.39215365672145797}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 15:58:49,406] Trial 7 finished with value: 0.8732702292271272 and parameters: {'preprocessor': 'no_punct', 'n_features_pow': 16, 'ngram_max': 3, 'alpha': 0.0009916280270649753, 'penalty': 'elasticnet', 'max_iter': 1536, 'l1_ratio': 0.6857322170929742}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 16:02:36,065] Trial 8 finished with value: 0.9905789796463106 and parameters: {'preprocessor': 'simple', 'n_features_pow': 14, 'ngram_max': 4, 'alpha': 2.0705070272595225e-06, 'penalty': 'elasticnet', 'max_iter': 1429, 'l1_ratio': 0.31008722277758416}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 16:06:14,285] Trial 9 finished with value: 0.6727273639726694 and parameters: {'preprocessor': 'no_punct', 'n_features_pow': 13, 'ngram_max': 3, 'alpha': 0.004637333703955162, 'penalty': 'elasticnet', 'max_iter': 1751, 'l1_ratio': 0.5001738400478558}. Best is trial 1 with value: 0.9913250314610041.
# [I 2026-01-04 16:09:57,950] Trial 10 finished with value: 0.9932996227343254 and parameters: {'preprocessor': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 1.215371517811825e-06, 'penalty': 'l2', 'max_iter': 1027, 'l1_ratio': 0.0036241924323212396}. Best is trial 10 with value: 0.9932996227343254.
# [I 2026-01-04 16:14:44,093] Trial 11 finished with value: 0.9933939517301121 and parameters: {'preprocessor': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 1.1590502596244222e-06, 'penalty': 'l2', 'max_iter': 1051, 'l1_ratio': 0.02148514835968657}. Best is trial 11 with value: 0.9933939517301121.
# [I 2026-01-04 16:19:08,579] Trial 12 finished with value: 0.9935277839296548 and parameters: {'preprocessor': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 1.0801448301753784e-06, 'penalty': 'l2', 'max_iter': 1014, 'l1_ratio': 0.0065493865047142105}. Best is trial 12 with value: 0.9935277839296548.
# [I 2026-01-04 16:23:47,481] Trial 13 finished with value: 0.988882303110746 and parameters: {'preprocessor': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'alpha': 6.79461723628701e-06, 'penalty': 'l2', 'max_iter': 1040, 'l1_ratio': 0.2092295871036307}. Best is trial 12 with value: 0.9935277839296548.
# [I 2026-01-04 16:27:20,206] Trial 14 finished with value: 0.9884785070743395 and parameters: {'preprocessor': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'alpha': 7.4657946345322174e-06, 'penalty': 'l2', 'max_iter': 1101, 'l1_ratio': 0.18220043873809244}. Best is trial 12 with value: 0.9935277839296548.
# [I 2026-01-04 16:31:18,198] Trial 15 finished with value: 0.9936439644161729 and parameters: {'preprocessor': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 1.0037269482365805e-06, 'penalty': 'l2', 'max_iter': 851, 'l1_ratio': 0.3450976726144354}. Best is trial 15 with value: 0.9936439644161729.
# [I 2026-01-04 16:35:30,458] Trial 16 finished with value: 0.9365793489127103 and parameters: {'preprocessor': 'simple', 'n_features_pow': 18, 'ngram_max': 5, 'alpha': 0.0003354726627273721, 'penalty': 'l2', 'max_iter': 825, 'l1_ratio': 0.36712016657599783}. Best is trial 15 with value: 0.9936439644161729.
# [I 2026-01-04 16:39:26,704] Trial 17 finished with value: 0.9898679026328868 and parameters: {'preprocessor': 'simple', 'n_features_pow': 17, 'ngram_max': 5, 'alpha': 4.962902462792764e-06, 'penalty': 'l2', 'max_iter': 1228, 'l1_ratio': 0.9784167827509016}. Best is trial 15 with value: 0.9936439644161729.
# [I 2026-01-04 16:43:43,669] Trial 18 finished with value: 0.9835846868387873 and parameters: {'preprocessor': 'simple', 'n_features_pow': 20, 'ngram_max': 5, 'alpha': 1.9963810454484328e-05, 'penalty': 'l2', 'max_iter': 830, 'l1_ratio': 0.2553975090406669}. Best is trial 15 with value: 0.9936439644161729.
# [I 2026-01-04 16:48:18,594] Trial 19 finished with value: 0.9913077068310824 and parameters: {'preprocessor': 'simple', 'n_features_pow': 19, 'ngram_max': 5, 'alpha': 3.159659682969337e-06, 'penalty': 'l2', 'max_iter': 1282, 'l1_ratio': 0.12909105570017443}. Best is trial 15 with value: 0.9936439644161729.

# %%
study.best_params
# Out:
# {'preprocessor': 'simple',
#  'n_features_pow': 20,
#  'ngram_max': 5,
#  'alpha': 1.0037269482365805e-06,
#  'penalty': 'l2',
#  'max_iter': 851,
#  'l1_ratio': 0.3450976726144354}

# %% [markdown]
# ### Saving model

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our preprocessor parameter ended up being simple, we can skip the preprocessor parameter in our HashingVectorizer in final pipeline because it just returns a text itself.

# %%
sgd_model_path = "../../models/dev/sgd_language_detection_model.joblib"

# %%
params = study.best_params

final_sgd_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1, params["ngram_max"]),
    n_features=2 ** params["n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

final_sgd_clf = SGDClassifier(
    loss='log_loss',
    penalty=params["penalty"],
    alpha=params["alpha"],
    l1_ratio=params["l1_ratio"],
    class_weight="balanced",
    random_state=RANDOM_STATE,
    n_jobs=N_JOBS
)

final_sgd_pipeline = Pipeline([
    ("vectorizer", final_sgd_vectorizer),
    ("classifier", final_sgd_clf)
])

# %%
final_sgd_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer',
#                  HashingVectorizer(analyzer='char_wb', ngram_range=(1, 5))),
#                 ('classifier',
#                  SGDClassifier(alpha=1.0037269482365805e-06,
#                                class_weight='balanced',
#                                l1_ratio=0.3450976726144354, loss='log_loss',
#                                n_jobs=6, random_state=0))])

# %%
joblib.dump(final_sgd_pipeline, sgd_model_path)
# Out:
# ['../../models/dev/sgd_language_detection_model.joblib']
