# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import optuna
import joblib

from typing import List
import string

# %%
RANDOM_STATE = 0
N_JOBS = 6

# %% [markdown]
# # Reading data

# %%
train_df = pd.read_csv("data/processed/train_russian_spam_detection_dataset.csv")
train_df.head()
# Out:
#                                              message  spam
# 0  Самые торгуемые опционные контракты сегодня aa...     0
# 1  Налог на прибыль организаций это прямой налог,...     0
# 2  Давай димон еще 4 стрима помнится сам как то с...     0
# 3  Вы же не думаете что масса людей это наш после...     0
# 4  Хотите для каждого, хотите засуньте их все в 1...     0

# %%
len(train_df)
# Out:
# 4311513

# %%
train_df.groupby("spam").count()
# Out:
#       message
# spam
# 0     3979858
# 1      331655

# %% [markdown]
# As we've mentioned earlier, this dataset has a huge class imbalance and is huge by it's size. We're gonna downsample it. Due to the fact that we have 331k+ rows of minority class (which is a lot) we're gonna downsample majority class to achieve a 1:1 ratio.

# %%
majority_class = train_df[train_df["spam"] == 0]
minority_class = train_df[train_df["spam"] == 1]

majority_downsampled = majority_class.sample(
    n=len(minority_class), 
    random_state=RANDOM_STATE
)

balanced_df = pd.concat([majority_downsampled, minority_class])
balanced_df = balanced_df.sample(
    frac=1, 
    random_state=RANDOM_STATE
).reset_index(drop=True)

print(balanced_df["spam"].value_counts())
# Out:
# spam
# 1    331655
# 0    331655
# Name: count, dtype: int64

# %%
X_train = balanced_df["message"]
y_train = balanced_df["spam"]

# %% [markdown]
# # Encoders

# %% [markdown]
# In this section we'll compare the learning speed of several different encoders for our texts as well as prepare different preprocessing approaches.

# %% [markdown]
# We should also note that all of our encoders are gonna tokenize text by characters and not by words for the reason that is we're trying to classify text and not to find some deep semantic meaning of it, for which separation by characters is a much better approach (it can handle typos and only "looks" for the character distribution by which language can be determined pretty accurately, but we still may be caring for characters order and for this reason we're gonna use custom n-grams parameter values).

# %% [markdown]
# ## Preprocessors

# %% [markdown]
# In this section we're gonna write some simple different preprocessors.

# %%
def simple_preprocessor(text: str) -> str:
    return text

# %%
def no_punctuation_preprocessor(text: str) -> str:
    blacklist_chars = string.punctuation
    translation_table = str.maketrans("", "", blacklist_chars)
    cleaned_text = text.translate(translation_table)
    return cleaned_text

# %%
preprocessors = {
    "simple": simple_preprocessor,
    "no_punct": no_punctuation_preprocessor
}

# %% [markdown]
# We're also gonna copy our preprocessor functions as a custom model to the file located at `../../app/models/transformers.py` in order to be able to use them from anywhere later without need to redefine them (and we also may need this for our final model to work properly).

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# scikin-learn's implementation of TF-IDF is offline, which means that it keeps everything in-memory and should be trained in one run. It may not be viable for training and tuning our models, but we still gonna check the perfomance of this approach as well.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    analyzer='char_wb', # We're caring only about characters in word bounds
    ngram_range=(1,3),
    max_features=100000,
    preprocessor=no_punctuation_preprocessor,
    lowercase=True,
)

# %% [markdown]
# Note that we're not using stopwords as they can be a crutial part in differentiating between languages from one language family (exactly Russian and Ukrainian).

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='char_wb', max_features=100000, ngram_range=(1, 3),
#                 preprocessor=<function no_punctuation_preprocessor at 0x0000013992D42980>)

# %% [markdown]
# As we can see, this TF-IDF implementation has been training for a pretty long time considering that we'll be tuning hyperparameters of both encoder and our classification model, so we're not likely to use it considering that it is also an offline implementation.

# %% [markdown]
# ## HashingVectorizer

# %% [markdown]
# HashingVectorizer is an online approach, which means that we can partially train it. Also, its scikit-learn implementation should be noticably faster than the implementation of TF-IDF (although it's resuls can be quite worse, but it's still faster to train which means that it's also faster to tune).

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(1,3),
    n_features=2**20,
    lowercase=True,
    preprocessor=no_punctuation_preprocessor
)

# %%
vectorizer.fit_transform(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 21098433 stored elements and shape (44963, 1048576)>

# %% [markdown]
# As this vectorizer is online, it's fit is stateless, but it's whole expensive computation is performed during transform stage. In result we can see, that it's still faster than TF-IDF, so we'll use it during our hyperparameters tuning.

# %% [markdown]
# # Models

# %% [markdown]
# We'll try two different models - SGDClassifier and Multinomial NaiveBayes, both of which are pretty popular in text classification tasks.
#
# We're not gonna try other popular models, such as XGBoost and LightGBM, in this specific case due to the fact that they are gonna consume a lot more memory (proportional to `amount of rows` * `amount of features`) and be much slower (time of execution is proportional to `amount of rows` * `amount of features` * `amount of trees (weak learners)`) than our two models of choice.

# %%
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import cross_val_score

# %%
from utils.models.transformers import TextCleaner
from utils.models.language_detector import LanguageDetector

# %% [markdown]
# ## SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd_model_path = "models/dev/sgd_russian_spam_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def sgdclassifier_objective(trial: optuna.Trial):
    # Word ngrams
    word_n_features_pow = trial.suggest_int("word_n_features_pow", 16, 21)
    word_ngram_max = trial.suggest_int("word_ngram_max", 1, 3)

    word_vectorizer = HashingVectorizer(
        analyzer='word',
        ngram_range=(1, word_ngram_max),
        n_features=2 ** word_n_features_pow,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # Characters inside words ngrams
    char_n_features_pow = trial.suggest_int("char_n_features_pow", 14, 18)
    char_ngram_min = trial.suggest_int("char_ngram_min", 2, 3)
    char_ngram_max = trial.suggest_int("char_ngram_max", 4, 6)

    char_vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(char_ngram_min, char_ngram_max),
        n_features=2 ** char_n_features_pow,
        alternate_sign=True,
        norm='l2',
        lowercase=True
    )

    # Combined features vectorizer
    combined_features_vectorizer = FeatureUnion([
        ("word_features", word_vectorizer),
        ("char_features", char_vectorizer),
    ])

    # SGDClassifier hyperparameters
    alpha = trial.suggest_float("alpha", 1e-6, 1e-1, log=True)
    penalty = trial.suggest_categorical("penalty", ["l2", "elasticnet"])

    # ElasticNet mixing parameter, will be ignored by model if penalty is l2
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)

    clf = SGDClassifier(
        loss='log_loss', # LogisticRegression
        penalty=penalty,
        alpha=alpha,
        l1_ratio=l1_ratio,
        class_weight="balanced", # Crutial because we have big class imbalance in our training dataset
        random_state=RANDOM_STATE,
        n_jobs=N_JOBS
    )

    pipeline = Pipeline([
        ("features_vectorizer", combined_features_vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %% [markdown]
# Note that we skipped max_iter parameter because it does not impact partial_fit behaviour according to https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html.

# %%
study = optuna.create_study(direction="maximize")
study.optimize(sgdclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-02-18 09:34:00,208] A new study created in memory with name: no-name-d93b5061-e347-4eb9-a643-7704813762dc
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-02-18 09:38:12,754] Trial 0 finished with value: 0.960646202464979 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 0.0001862976472505031, 'penalty': 'l2', 'l1_ratio': 0.8041399359143132}. Best is trial 0 with value: 0.960646202464979.
# [I 2026-02-18 09:40:44,853] Trial 1 finished with value: 0.6396076563776117 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 1, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 0.01726521649576486, 'penalty': 'elasticnet', 'l1_ratio': 0.5489619709906979}. Best is trial 0 with value: 0.960646202464979.
# [I 2026-02-18 09:43:04,743] Trial 2 finished with value: 0.9832722584908247 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 2, 'char_n_features_pow': 18, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 5.185100660220117e-06, 'penalty': 'l2', 'l1_ratio': 0.5213261121345528}. Best is trial 2 with value: 0.9832722584908247.
# [I 2026-02-18 09:45:11,257] Trial 3 finished with value: 0.9738593010148117 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 1.2936325756788566e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.7852149487217108}. Best is trial 2 with value: 0.9832722584908247.
# [I 2026-02-18 09:49:37,187] Trial 4 finished with value: 0.9734451657801554 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 3, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 3.4742483428048224e-05, 'penalty': 'l2', 'l1_ratio': 0.6242306217609116}. Best is trial 2 with value: 0.9832722584908247.
# [I 2026-02-18 09:53:20,244] Trial 5 finished with value: 0.9873403942451975 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 1.6314255823172174e-06, 'penalty': 'l2', 'l1_ratio': 0.04079612557264234}. Best is trial 5 with value: 0.9873403942451975.
# [I 2026-02-18 09:55:11,816] Trial 6 finished with value: 0.9873373644737781 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 1, 'char_n_features_pow': 17, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 1.143026031484215e-06, 'penalty': 'l2', 'l1_ratio': 0.17221794914756705}. Best is trial 5 with value: 0.9873403942451975.
# [I 2026-02-18 09:57:34,571] Trial 7 finished with value: 0.9584754793411777 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 2, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.00019996346505809815, 'penalty': 'l2', 'l1_ratio': 0.025850309372757674}. Best is trial 5 with value: 0.9873403942451975.
# [I 2026-02-18 10:01:14,953] Trial 8 finished with value: 0.33323193553297425 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 1, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 0.041121168276169136, 'penalty': 'elasticnet', 'l1_ratio': 0.7218483895962139}. Best is trial 5 with value: 0.9873403942451975.
# [I 2026-02-18 10:03:32,915] Trial 9 finished with value: 0.984377585387285 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 1, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 3.726469526156698e-06, 'penalty': 'l2', 'l1_ratio': 0.8621123466685281}. Best is trial 5 with value: 0.9873403942451975.
# [I 2026-02-18 10:08:22,145] Trial 10 finished with value: 0.8986021597316368 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 3, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 0.0034290104062390816, 'penalty': 'elasticnet', 'l1_ratio': 0.2607606556466543}. Best is trial 5 with value: 0.9873403942451975.
# [I 2026-02-18 10:10:32,576] Trial 11 finished with value: 0.985434554129846 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 1, 'char_n_features_pow': 17, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 2.594316967249979e-06, 'penalty': 'l2', 'l1_ratio': 0.028538732225913604}. Best is trial 5 with value: 0.9873403942451975.
# [I 2026-02-18 10:13:02,165] Trial 12 finished with value: 0.9881214363173264 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 1, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 1.0246614518451648e-06, 'penalty': 'l2', 'l1_ratio': 0.24440908957817575}. Best is trial 12 with value: 0.9881214363173264.
# [I 2026-02-18 10:16:05,503] Trial 13 finished with value: 0.9749745530017027 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 2, 'char_n_features_pow': 16, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 3.235757254154212e-05, 'penalty': 'l2', 'l1_ratio': 0.27580663746545964}. Best is trial 12 with value: 0.9881214363173264.
# [I 2026-02-18 10:18:47,362] Trial 14 finished with value: 0.987931455610117 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 1.0918515672217035e-06, 'penalty': 'l2', 'l1_ratio': 0.3508790389358605}. Best is trial 12 with value: 0.9881214363173264.
# [I 2026-02-18 10:20:57,409] Trial 15 finished with value: 0.939084615551869 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 2, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 0.001234717036915295, 'penalty': 'l2', 'l1_ratio': 0.38572248828144695}. Best is trial 12 with value: 0.9881214363173264.
# [I 2026-02-18 10:24:02,615] Trial 16 finished with value: 0.975544829672801 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 1, 'char_n_features_pow': 16, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 3.3650994070853185e-05, 'penalty': 'l2', 'l1_ratio': 0.3926848380679398}. Best is trial 12 with value: 0.9881214363173264.
# [I 2026-02-18 10:26:45,131] Trial 17 finished with value: 0.9805112243302899 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 2, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 1.1824446644037031e-05, 'penalty': 'l2', 'l1_ratio': 0.39533233806415935}. Best is trial 12 with value: 0.9881214363173264.
# [I 2026-02-18 10:30:00,624] Trial 18 finished with value: 0.9553792625107128 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 3, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 7.405139749247928e-05, 'penalty': 'elasticnet', 'l1_ratio': 0.9871316699029808}. Best is trial 12 with value: 0.9881214363173264.
# [I 2026-02-18 10:31:59,067] Trial 19 finished with value: 0.9879631316182763 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 1, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 1.006751655181542e-06, 'penalty': 'l2', 'l1_ratio': 0.17664266812342955}. Best is trial 12 with value: 0.9881214363173264.

# %%
study.best_params
# Out:
# {'word_n_features_pow': 18,
#  'word_ngram_max': 1,
#  'char_n_features_pow': 17,
#  'char_ngram_min': 2,
#  'char_ngram_max': 4,
#  'alpha': 1.0246614518451648e-06,
#  'penalty': 'l2',
#  'l1_ratio': 0.24440908957817575}

# %% [markdown]
# ```
# {'word_n_features_pow': 18,
#  'word_ngram_max': 1,
#  'char_n_features_pow': 17,
#  'char_ngram_min': 2,
#  'char_ngram_max': 4,
#  'alpha': 1.0246614518451648e-06,
#  'penalty': 'l2',
#  'l1_ratio': 0.24440908957817575}
# ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters into a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
sgd_best_params = {
    'word_n_features_pow': 18,
    'word_ngram_max': 1,
    'char_n_features_pow': 17,
    'char_ngram_min': 2,
    'char_ngram_max': 4,
    'alpha': 1.0246614518451648e-06,
    'penalty': 'l2',
    'l1_ratio': 0.24440908957817575
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    sgd_params = study.best_params
except:
    sgd_params = sgd_best_params 

word_vectorizer = HashingVectorizer(
    analyzer='word',
    ngram_range=(1, sgd_params["word_ngram_max"]),
    n_features=2 ** sgd_params["word_n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

char_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(sgd_params["char_ngram_min"], sgd_params["char_ngram_max"]),
    n_features=2 ** sgd_params["char_n_features_pow"],
    alternate_sign=True,
    norm='l2',
    lowercase=True
)

combined_features_vectorizer = FeatureUnion([
    ("word_features", word_vectorizer),
    ("char_features", char_vectorizer),
])

final_sgd_clf = SGDClassifier(
    loss='log_loss',
    penalty=sgd_params["penalty"],
    alpha=sgd_params["alpha"],
    l1_ratio=sgd_params["l1_ratio"],
    class_weight="balanced",
    random_state=RANDOM_STATE,
    n_jobs=N_JOBS
)

sgd_spam_detector = Pipeline([
    ("features_vectorizer", combined_features_vectorizer),
    ("classifier", final_sgd_clf)
])

# %%
sgd_spam_detector.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('features_vectorizer',
#                  FeatureUnion(transformer_list=[('word_features',
#                                                  HashingVectorizer(n_features=262144)),
#                                                 ('char_features',
#                                                  HashingVectorizer(analyzer='char_wb',
#                                                                    n_features=131072,
#                                                                    ngram_range=(2,
#                                                                                 4)))])),
#                 ('classifier',
#                  SGDClassifier(alpha=1.0246614518451648e-06,
#                                class_weight='balanced',
#                                l1_ratio=0.24440908957817575, loss='log_loss',
#                                n_jobs=6, random_state=0))])

# %%
joblib.dump(sgd_spam_detector, sgd_model_path)
# Out:
# ['models/dev/sgd_russian_spam_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
sgd_model = joblib.load(sgd_model_path)
sgd_model
# Out:
# Pipeline(steps=[('features_vectorizer',
#                  FeatureUnion(transformer_list=[('word_features',
#                                                  HashingVectorizer(n_features=262144)),
#                                                 ('char_features',
#                                                  HashingVectorizer(analyzer='char_wb',
#                                                                    n_features=131072,
#                                                                    ngram_range=(2,
#                                                                                 4)))])),
#                 ('classifier',
#                  SGDClassifier(alpha=1.0246614518451648e-06,
#                                class_weight='balanced',
#                                l1_ratio=0.24440908957817575, loss='log_loss',
#                                n_jobs=6, random_state=0))])

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!

# %% [markdown]
# ## MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb_model_path = "models/dev/mnb_russian_spam_detection_model.joblib"

# %% [markdown]
# ### Tuning

# %%
def mnbclassifier_objective(trial: optuna.Trial):
    # Word ngrams
    word_n_features_pow = trial.suggest_int("word_n_features_pow", 16, 21)
    word_ngram_max = trial.suggest_int("word_ngram_max", 1, 3)

    word_vectorizer = HashingVectorizer(
        analyzer='word',
        ngram_range=(1, word_ngram_max),
        n_features=2 ** word_n_features_pow,
        alternate_sign=False, # Values must be non-negative for MultinomialNB
        norm='l2',
        lowercase=True
    )

    # Characters inside words ngrams
    char_n_features_pow = trial.suggest_int("char_n_features_pow", 14, 18)
    char_ngram_min = trial.suggest_int("char_ngram_min", 2, 3)
    char_ngram_max = trial.suggest_int("char_ngram_max", 4, 6)

    char_vectorizer = HashingVectorizer(
        analyzer='char_wb',
        ngram_range=(char_ngram_min, char_ngram_max),
        n_features=2 ** char_n_features_pow,
        alternate_sign=False, # Values must be non-negative for MultinomialNB
        norm='l2',
        lowercase=True
    )

    # Combined features vectorizer
    combined_features_vectorizer = FeatureUnion([
        ("word_features", word_vectorizer),
        ("char_features", char_vectorizer),
    ])

    # MultinomialNB hyperparameters
    alpha = trial.suggest_float("alpha", 1e-10, 10.0, log=True)
    fit_prior = trial.suggest_categorical("fit_prior", [True, False])

    clf = MultinomialNB(
        alpha=alpha,
        fit_prior=fit_prior
    )

    pipeline = Pipeline([
        ("features_vectorizer", combined_features_vectorizer),
        ("classifier", clf)
    ])

    language_detector = LanguageDetector(pipeline)

    scores = cross_val_score(
        language_detector,
        X_train,
        y_train,
        cv=3,
        scoring="f1_macro", # Because of our class imbalance
        n_jobs=N_JOBS
    )

    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(mnbclassifier_objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2026-02-18 10:37:32,764] A new study created in memory with name: no-name-ff9186e0-ef50-4ae0-b504-b650435c6523
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2026-02-18 10:39:45,497] Trial 0 finished with value: 0.9506214361775566 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 2, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 4, 'alpha': 9.008159352711696e-08, 'fit_prior': False}. Best is trial 0 with value: 0.9506214361775566.
# [I 2026-02-18 10:42:17,168] Trial 1 finished with value: 0.9546031294961409 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 1, 'char_n_features_pow': 17, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 0.0007880095389514799, 'fit_prior': True}. Best is trial 1 with value: 0.9546031294961409.
# [I 2026-02-18 10:44:26,228] Trial 2 finished with value: 0.9486988439817927 and parameters: {'word_n_features_pow': 16, 'word_ngram_max': 2, 'char_n_features_pow': 15, 'char_ngram_min': 3, 'char_ngram_max': 6, 'alpha': 1.2226771119856548, 'fit_prior': True}. Best is trial 1 with value: 0.9546031294961409.
# [I 2026-02-18 10:46:47,885] Trial 3 finished with value: 0.9574114075263455 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 1, 'char_n_features_pow': 18, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 1.0678539968924311e-06, 'fit_prior': False}. Best is trial 3 with value: 0.9574114075263455.
# [I 2026-02-18 10:49:03,439] Trial 4 finished with value: 0.9595177062804524 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 0.12126559192284139, 'fit_prior': False}. Best is trial 4 with value: 0.9595177062804524.
# [I 2026-02-18 10:52:59,963] Trial 5 finished with value: 0.9518952361200629 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 3, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 7.746559816648328e-08, 'fit_prior': False}. Best is trial 4 with value: 0.9595177062804524.
# [I 2026-02-18 10:55:15,506] Trial 6 finished with value: 0.9574738104224005 and parameters: {'word_n_features_pow': 17, 'word_ngram_max': 1, 'char_n_features_pow': 17, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 0.0006191185448877705, 'fit_prior': True}. Best is trial 4 with value: 0.9595177062804524.
# [I 2026-02-18 10:56:43,733] Trial 7 finished with value: 0.9558377689355884 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 2, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 5.991443730982428e-08, 'fit_prior': False}. Best is trial 4 with value: 0.9595177062804524.
# [I 2026-02-18 11:00:17,659] Trial 8 finished with value: 0.9667388225361124 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 1, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 0.00010080591653645754, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:02:07,277] Trial 9 finished with value: 0.9586575967558918 and parameters: {'word_n_features_pow': 18, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 0.053878678847209004, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:06:04,963] Trial 10 finished with value: 0.9373489854879479 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 3, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 1.0758163657601276e-10, 'fit_prior': True}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:07:56,939] Trial 11 finished with value: 0.9613732412704353 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 6.128423998007421, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:11:45,708] Trial 12 finished with value: 0.956942046127748 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 3, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 6.580402901035123, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:13:31,007] Trial 13 finished with value: 0.9664391760524328 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 1, 'char_n_features_pow': 14, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 3.8741031914482315e-05, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:16:54,906] Trial 14 finished with value: 0.964308621284759 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 2, 'char_ngram_max': 6, 'alpha': 6.668314163860377e-05, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:18:42,983] Trial 15 finished with value: 0.9647696653658953 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 1, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 5, 'alpha': 4.015087546425969e-06, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:21:47,921] Trial 16 finished with value: 0.9640374279316543 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 1, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 0.0006926682958454921, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:23:48,001] Trial 17 finished with value: 0.9654886183343607 and parameters: {'word_n_features_pow': 21, 'word_ngram_max': 1, 'char_n_features_pow': 15, 'char_ngram_min': 3, 'char_ngram_max': 6, 'alpha': 0.008332918535864535, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:25:29,910] Trial 18 finished with value: 0.9612528424997161 and parameters: {'word_n_features_pow': 19, 'word_ngram_max': 1, 'char_n_features_pow': 16, 'char_ngram_min': 3, 'char_ngram_max': 4, 'alpha': 2.3879975053965208e-05, 'fit_prior': True}. Best is trial 8 with value: 0.9667388225361124.
# [I 2026-02-18 11:28:04,131] Trial 19 finished with value: 0.9460425119648 and parameters: {'word_n_features_pow': 20, 'word_ngram_max': 2, 'char_n_features_pow': 14, 'char_ngram_min': 2, 'char_ngram_max': 5, 'alpha': 2.5280714612208806e-10, 'fit_prior': False}. Best is trial 8 with value: 0.9667388225361124.

# %%
study.best_params
# Out:
# {'word_n_features_pow': 21,
#  'word_ngram_max': 1,
#  'char_n_features_pow': 14,
#  'char_ngram_min': 2,
#  'char_ngram_max': 6,
#  'alpha': 0.00010080591653645754,
#  'fit_prior': False}

# %% [markdown]
# ```
# {'word_n_features_pow': 21,
#  'word_ngram_max': 1,
#  'char_n_features_pow': 14,
#  'char_ngram_min': 2,
#  'char_ngram_max': 6,
#  'alpha': 0.00010080591653645754,
#  'fit_prior': False}
#  ```

# %% [markdown]
# ### Saving model

# %% [markdown]
# We'll save best parameters to a separate variable in order to not need to go through hyperparameter tuning once again to get them.

# %%
mnb_best_params = {
    'word_n_features_pow': 21,
    'word_ngram_max': 1,
    'char_n_features_pow': 14,
    'char_ngram_min': 2,
    'char_ngram_max': 6,
    'alpha': 0.00010080591653645754,
    'fit_prior': False
}

# %% [markdown]
# Now we're gonna save our model using joblib in order to not go through hyperparameter tuning stage again in the future.
#
# As our text cleaner parameter ended up being `simple`, our model will lead best perfomance without additional preprocessing applied on text.

# %%
try:
    mnb_params = study.best_params
except:
    mnb_params = mnb_best_params 

word_vectorizer = HashingVectorizer(
    analyzer='word',
    ngram_range=(1, mnb_params["word_ngram_max"]),
    n_features=2 ** mnb_params["word_n_features_pow"],
    alternate_sign=False,
    norm='l2',
    lowercase=True
)

char_vectorizer = HashingVectorizer(
    analyzer='char_wb',
    ngram_range=(mnb_params["char_ngram_min"], mnb_params["char_ngram_max"]),
    n_features=2 ** mnb_params["char_n_features_pow"],
    alternate_sign=False,
    norm='l2',
    lowercase=True
)

combined_features_vectorizer = FeatureUnion([
    ("word_features", word_vectorizer),
    ("char_features", char_vectorizer),
])

final_mnb_clf = MultinomialNB(
    alpha=mnb_params["alpha"],
    fit_prior=mnb_params["fit_prior"]
)

mnb_spam_detector = Pipeline([
    ("features_vectorizer", combined_features_vectorizer),
    ("classifier", final_mnb_clf)
])

# %%
mnb_spam_detector.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('features_vectorizer',
#                  FeatureUnion(transformer_list=[('word_features',
#                                                  HashingVectorizer(alternate_sign=False,
#                                                                    n_features=2097152)),
#                                                 ('char_features',
#                                                  HashingVectorizer(alternate_sign=False,
#                                                                    analyzer='char_wb',
#                                                                    n_features=16384,
#                                                                    ngram_range=(2,
#                                                                                 6)))])),
#                 ('classifier',
#                  MultinomialNB(alpha=0.00010080591653645754, fit_prior=False))])

# %%
joblib.dump(mnb_spam_detector, mnb_model_path)
# Out:
# ['models/dev/mnb_russian_spam_detection_model.joblib']

# %% [markdown]
# ### Loading model

# %% [markdown]
# And now we can load our already tuned model and see it's structure.

# %%
mnb_model = joblib.load(mnb_model_path)
mnb_model
# Out:
# Pipeline(steps=[('features_vectorizer',
#                  FeatureUnion(transformer_list=[('word_features',
#                                                  HashingVectorizer(alternate_sign=False,
#                                                                    n_features=2097152)),
#                                                 ('char_features',
#                                                  HashingVectorizer(alternate_sign=False,
#                                                                    analyzer='char_wb',
#                                                                    n_features=16384,
#                                                                    ngram_range=(2,
#                                                                                 6)))])),
#                 ('classifier',
#                  MultinomialNB(alpha=0.00010080591653645754, fit_prior=False))])

# %% [markdown]
# As we've stated earlier, we can use our model as-is - no additional text preprocessing needed!
